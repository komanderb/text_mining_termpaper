# %% [markdown]
# ## Words around female and characters and co-occurence matrix

# %%
import pandas as pd
import numpy as np 
import sklearn
import seaborn as sns
import pandas as pd
from pathlib import Path
import os
import sys
import csv
import numpy as np

import nltk                                                             # Natural language Toolkit
from nltk.stem import SnowballStemmer                                   # Porter's II Stemmer
from nltk import word_tokenize                                          # Document tokenizer
from nltk.corpus import stopwords  
#nltk.download('wordnet')
#nltk.download('omw-1.4')

from nltk.tokenize import word_tokenize 
import nltk
from nltk.stem import WordNetLemmatizer

from nltk.tokenize import RegexpTokenizer

# %%
from pandas.core.common import flatten

# %% [markdown]
# ## extract sentences with female/male names

# %% [markdown]
# the "Cinderella complex" paper (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6874350/):
# 1. we select five words before and five words after the names of the leading characters across all the sentences.
# 2. We iterate over the pairwise combinations of words within 10-word samples across all movie synopses to create a word co-occurrence matrix
# 3. construct word co-occurrence networks, one for females and the other for male

# %%
df=pd.read_csv("preprocessed_corpus.csv")

# %%
stopwords = nltk.corpus.stopwords.words('english')
remove_pronouns=['he',
 'him',
 'his',
 'himself',
 'she',
 "she's",
 'her',
 'hers',
 'herself']
# stopwords = [word for word in remove_pronouns if word not in stopwords]

# %%
stopwords_wo_pronoun=list(set(stopwords)-set(remove_pronouns))

# %%
# split text to sentences
sentences=df["clean_text2"].apply(nltk.sent_tokenize)

# %%
sentences[0]
# Out:
# ["[illustration] alice's adventures wonderland lewis carroll millennium fulcrum edition 3.0 contents   rabbit-hole   pool tears   caucus-race long tale   rabbit sends little bill   advice caterpillar   pig pepper   mad tea-party   queen's croquet-ground  ix.",
#  "mock turtle's story   lobster quadrille   stole tarts?",
#  'alice\'s evidence   rabbit-hole alice beginning get tired sitting her sister bank, nothing do: twice she peeped book her sister reading, pictures conversations it, "and use book," thought alice "without pictures conversations?"',
#  'she considering her mind (as well she could, hot day made her feel sleepy stupid), whether pleasure making daisy-chain would worth trouble getting picking daisies, suddenly white rabbit pink eyes ran close her.',
#  'nothing very remarkable that; alice think very much way hear rabbit say itself, "oh dear!',
#  'oh dear!',
#  'shall late!"',
#  '(when she thought afterwards, occurred her she ought wondered this, time seemed quite natural); rabbit actually took watch waistcoat-pocket, looked it, hurried on, alice started her feet, flashed across her mind she never seen rabbit either waistcoat-pocket, watch take it, burning curiosity, she ran across field it, fortunately time see pop large rabbit-hole hedge.',
#  'another moment went alice it, never considering world she get again.',
#  'rabbit-hole went straight like tunnel way, dipped suddenly down, suddenly alice moment think stopping herself she found herself falling deep well.',
#  'either well deep, she fell slowly, she plenty time she went look her wonder going happen next.',
#  'first, she tried look make she coming to, dark see anything; she looked sides well, noticed filled cupboards book-shelves; she saw maps pictures hung upon pegs.',
#  'she took jar one shelves she passed; labelled "orange marmalade", her great disappointment empty: she like drop jar fear killing somebody underneath, managed put one cupboards she fell past it.',
#  '"well!"',
#  'thought alice herself, "after fall this, shall think nothing tumbling stairs!',
#  "brave they'll think home!",
#  'why, say anything it, even fell top house!"',
#  '(which likely true.)',
#  'down, down, down.',
#  'would fall never come end? "',
#  'wonder many miles \'ve fallen time?"',
#  'she said aloud. "',
#  'must getting somewhere near centre earth.',
#  'let see: would four thousand miles down, think-" (for, see, alice learnt several things sort her lessons schoolroom, though very good opportunity showing her knowledge, one listen her, still good practice say over) "-yes, that\'s right distance-but wonder latitude longitude \'ve got to?"',
#  '(alice idea latitude was, longitude either, thought nice grand words say.)',
#  'presently she began again. "',
#  'wonder shall fall right through earth!',
#  "funny it'll seem come among people walk heads downward!",
#  'antipathies, think-" (she rather glad was one listening, time, sound right word) "-but shall ask name country is, know.',
#  'please, ma\'am, new zealand australia?"',
#  '(and she tried curtsey she spoke-fancy curtseying falling air!',
#  'think could manage it?)',
#  '"and ignorant little girl she\'ll think asking!',
#  'no, it\'ll never ask: perhaps shall see written somewhere."',
#  'down, down, down.',
#  'nothing else do, alice soon began talking again.',
#  '"dinah\'ll miss much to-night, think!"',
#  '(dinah cat.)',
#  '" hope they\'ll remember her saucer milk tea-time.',
#  'dinah dear!',
#  'wish me!',
#  "mice air, ' afraid, might catch bat, that's like mouse, know.",
#  'cats eat bats, wonder?"',
#  'alice began get rather sleepy, went saying herself, dreamy sort way, "do cats eat bats?',
#  'cats eat bats?"',
#  'sometimes, "do bats eat cats?"',
#  'for, see, she answer either question, much matter way she put it.',
#  'she felt she dozing off, begun dream she walking hand hand dinah, saying her earnestly, "now, dinah, tell truth: ever eat bat?"',
#  'suddenly, thump!',
#  'thump!',
#  'she came upon heap sticks dry leaves, fall over.',
#  'alice bit hurt, she jumped her feet moment: she looked up, dark overhead; her another long passage, white rabbit still sight, hurrying it.',
#  'moment lost: away went alice like wind, time hear say, turned corner, "oh ears whiskers, late getting!"',
#  'she close behind she turned corner, rabbit longer seen: she found herself long, low hall, lit row lamps hanging roof.',
#  'doors round hall, locked; alice way one side other, trying every door, she walked sadly middle, wondering she ever get again.',
#  "suddenly she came upon little three-legged table, made solid glass; nothing except tiny golden key, alice's first thought might belong one doors hall; but, alas!",
#  'either locks large, key small, rate would open them.',
#  'however, second time round, she came upon low curtain she noticed before, behind little door fifteen inches high: she tried little golden key lock, her great delight fitted!',
#  'alice opened door found led small passage, much larger rat-hole: she knelt looked along passage loveliest garden ever saw.',
#  'she longed get dark hall, wander among beds bright flowers cool fountains, she could even get her head doorway; "and even head would go through," thought poor alice, "it would little use without shoulders.',
#  'oh, wish could shut like telescope!',
#  'think could, knew begin."',
#  'for, see, many out-of-the-way things happened lately, alice begun think things indeed really impossible.',
#  'seemed use waiting little door, she went back table, half hoping she might find another key it, rate book rules shutting people like telescopes: time she found little bottle it, ("which certainly before," said alice,) round neck bottle paper label, words "drink me," beautifully printed large letters.',
#  'well say "drink me," wise little alice going that hurry.',
#  '"no, \'ll look first," she said, "and see whether marked \'poison\' not"; she read several nice little histories children got burnt, eaten wild beasts unpleasant things, would remember simple rules friends taught them: as, red-hot poker burn hold long; cut finger very deeply knife, usually bleeds; she never forgotten that, drink much bottle marked "poison," almost certain disagree you, sooner later.',
#  'however, bottle not marked "poison," alice ventured taste it, finding nice, (it had, fact, sort mixed flavour cherry-tart, custard, pine-apple, roast turkey, toffee, hot buttered toast,) she soon finished off.',
#  '"what curious feeling!"',
#  'said alice; " must shutting like telescope."',
#  'indeed: she ten inches high, her face brightened thought she right size going little door lovely garden.',
#  'first, however, she waited minutes see she going shrink further: she felt little nervous this; "for might end, know," said alice herself, "in going altogether, like candle.',
#  'wonder like then?"',
#  'she tried fancy flame candle like candle blown out, she could remember ever seen thing.',
#  'while, finding nothing happened, she decided going garden once; but, alas poor alice!',
#  'she got door, she found she forgotten little golden key, she went back table it, she found she could possibly reach it: she could see quite plainly glass, she tried her best climb one legs table, slippery; she tired herself trying, poor little thing sat cried.',
#  '"come, there\'s use crying like that!"',
#  'said alice herself, rather sharply; " advise leave minute!"',
#  'she generally gave herself good advice, (though she seldom followed it), sometimes she scolded herself severely bring tears her eyes; she remembered trying box her ears cheated herself game croquet she playing herself, curious child fond pretending two people.',
#  '"but use now," thought poor alice, "to pretend two people!',
#  'why, there\'s hardly enough left make one respectable person!"',
#  'soon her eye fell little glass box lying table: she opened it, found small cake, words "eat me" beautifully marked currants.',
#  '"well, \'ll eat it," said alice, "and makes grow larger, reach key; makes grow smaller, creep door; either way \'ll get garden, care happens!"',
#  'she ate little bit, said anxiously herself, "which way?',
#  'way?',
#  '", holding her hand top her head feel way growing, she quite surprised find she remained size: sure, generally happens one eats cake, alice got much way expecting nothing out-of-the-way things happen, seemed quite dull stupid life go common way.',
#  'she set work, soon finished cake.',
#  'pool tears "curiouser curiouser!"',
#  'cried alice (she much surprised, moment she quite forgot speak good english); "now \' opening like largest telescope ever was!',
#  'good-bye, feet!"',
#  '(for she looked her feet, seemed almost sight, getting far off).',
#  '"oh, poor little feet, wonder put shoes stockings now, dears? \'',
#  'sure  able!',
#  'shall great deal far trouble you: must manage best way can;-but must kind them," thought alice, "or perhaps walk way want go!',
#  'let see: \'ll give new pair boots every christmas."',
#  'she went planning herself she would manage it.',
#  '"they must go carrier," she thought; "and funny it\'ll seem, sending presents one\'s feet!',
#  'odd directions look!',
#  "alice's right foot, esq., hearthrug, near fender, (with alice's love).",
#  'oh dear, nonsense \' talking!"',
#  'her head struck roof hall: fact she nine feet high, she took little golden key hurried garden door.',
#  'poor alice!',
#  'much she could do, lying one side, look garden one eye; get hopeless ever: she sat began cry again.',
#  '"you ought ashamed yourself," said alice, "a great girl like you," (she might well say this), "to go crying way!',
#  'stop moment, tell you!"',
#  'she went same, shedding gallons tears, large pool round her, four inches deep reaching half hall.',
#  'time she heard little pattering feet distance, she hastily dried her eyes see coming.',
#  'white rabbit returning, splendidly dressed, pair white kid gloves one hand large fan other: he came trotting along great hurry, muttering himself he came, "oh!',
#  'duchess, duchess!',
#  'oh!',
#  'she savage \'ve kept her waiting!"',
#  'alice felt desperate she ready ask help one; so, rabbit came near her, she began, low, timid voice, "if please, sir-" rabbit started violently, dropped white kid gloves fan, skurried away darkness hard he could go.',
#  'alice took fan gloves, and, hall hot, she kept fanning herself time she went talking: "dear, dear!',
#  'queer everything to-day!',
#  'yesterday things went usual.',
#  "wonder 've changed night?",
#  'let think: got morning?',
#  "almost think remember feeling little different. '",
#  'same, next question is, world ?',
#  'ah, that\'s great puzzle!"',
#  'she began thinking children she knew age herself, see she could changed them. "\'',
#  'sure \' ada," she said, "for her hair goes long ringlets, mine go ringlets all; \' sure can\'t mabel, know sorts things, she, oh!',
#  'she knows little!',
#  "besides, she's she, ' , and-oh dear, puzzling is!",
#  "'ll try know things used know.",
#  'let see: four times five twelve, four times six thirteen, four times seven is-oh dear!',
#  'shall never get twenty rate!',
#  "however, multiplication table signify: let's try geography.",
#  "london capital paris, paris capital rome, rome-no, that's wrong, ' certain!",
#  'must changed mabel!',
#  '\'ll try say \'how doth little-\'" she crossed her hands her lap she saying lessons, began repeat it, her voice sounded hoarse strange, words come used do:- "how doth little crocodile improve his shining tail, pour waters nile every golden scale!',
#  '"how cheerfully he seems grin, neatly spread his claws, welcome little fishes gently smiling jaws!"',
#  '"\' sure right words," said poor alice, her eyes filled tears she went on, " must mabel all, shall go live poky little house, next toys play with, oh!',
#  'ever many lessons learn!',
#  "no, 've made mind it; ' mabel, 'll stay here!",
#  "it'll use putting heads saying 'come again, dear!'",
#  "shall look say 'who then?",
#  'tell first, then, like person, \'ll come up: not, \'ll stay till \' somebody else\'-but, oh dear!"',
#  'cried alice, sudden burst tears, " wish would put heads down!',
#  'very tired alone here!"',
#  "she said she looked her hands, surprised see she put one rabbit's little white kid gloves she talking.",
#  '"how can done that?"',
#  'she thought. "',
#  'must growing small again."',
#  'she got went table measure herself it, found that, nearly she could guess, she two feet high, going shrinking rapidly: she soon found cause fan she holding, she dropped hastily, time avoid shrinking away altogether.',
#  '"that was narrow escape!"',
#  'said alice, good deal frightened sudden change, glad find herself still existence; "and garden!"',
#  'she ran speed back little door: but, alas!',
#  'little door shut again, little golden key lying glass table before, "and things worse ever," thought poor child, "for never small before, never!',
#  'declare bad, is!"',
#  'she said words her foot slipped, another moment, splash!',
#  'she her chin salt water.',
#  'her first idea she somehow fallen sea, "and case go back railway," she said herself.',
#  '(alice seaside her life, come general conclusion, wherever go english coast find number bathing machines sea, children digging sand wooden spades, row lodging houses, behind railway station.)',
#  'however, she soon made she pool tears she wept she nine feet high. "',
#  'wish cried much!"',
#  'said alice, she swam about, trying find her way out. "',
#  'shall punished now, suppose, drowned tears!',
#  'will queer thing, sure!',
#  'however, everything queer to-day."',
#  'she heard something splashing pool little way off, she swam nearer make was: first she thought must walrus hippopotamus, she remembered small she now, she soon made mouse slipped like herself.',
#  '"would use, now," thought alice, "to speak mouse?',
#  'everything out-of-the-way here, think likely talk: rate, there\'s harm trying."',
#  'she began: "o mouse, know way pool?',
#  'tired swimming here, mouse!"',
#  '(alice thought must right way speaking mouse: she never done thing before, she remembered seen her brother\'s latin grammar, "a mouse-of mouse-to mouse-a mouse-o mouse!")',
#  'mouse looked her rather inquisitively, seemed her wink one little eyes, said nothing.',
#  '"perhaps understand english," thought alice; " daresay french mouse, come william conqueror."',
#  '(for, her knowledge history, alice clear notion long ago anything happened.)',
#  'she began again: "ou est chatte?"',
#  'first sentence her french lesson-book.',
#  'mouse gave sudden leap water, seemed quiver fright.',
#  '"oh, beg pardon!"',
#  'cried alice hastily, afraid she hurt poor animal\'s feelings. "',
#  'quite forgot like cats."',
#  '"not like cats!"',
#  'cried mouse, shrill, passionate voice.',
#  '"would you like cats me?"',
#  '"well, perhaps not," said alice soothing tone: "don\'t angry it.',
#  'yet wish could show cat dinah: think take fancy cats could see her.',
#  'she dear quiet thing," alice went on, half herself, she swam lazily pool, "and she sits purring nicely fire, licking her paws washing her face-and she nice soft thing nurse-and she\'s capital one catching mice-oh, beg pardon!"',
#  'cried alice again, time mouse bristling over, she felt certain must really offended.',
#  '"we talk her rather not."',
#  '"we indeed!"',
#  'cried mouse, trembling end his tail.',
#  '"as  would talk subject!',
#  'family always hated cats: nasty, low, vulgar things!',
#  'let hear name again!"',
#  '" indeed!"',
#  'said alice, great hurry change subject conversation.',
#  '"are you-are fond-of-of dogs?"',
#  'mouse answer, alice went eagerly: "there nice little dog near house like show you!',
#  'little bright-eyed terrier, know, oh, long curly brown hair!',
#  "it'll fetch things throw them, it'll sit beg dinner, sorts things- can't remember half them-and belongs farmer, know, he says useful, worth hundred pounds!",
#  'he says kills rats and-oh dear!"',
#  'cried alice sorrowful tone, "\' afraid \'ve offended again!"',
#  'mouse swimming away her hard could go, making quite commotion pool went.',
#  'she called softly it, "mouse dear!',
#  'come back again, talk cats dogs either, like them!"',
#  'mouse heard this, turned round swam slowly back her: face quite pale (with passion, alice thought), said low trembling voice, "let us get shore, \'ll tell history, understand hate cats dogs."',
#  'high time go, pool getting quite crowded birds animals fallen it: duck dodo, lory eaglet, several curious creatures.',
#  'alice led way, whole party swam shore.',
#  'caucus-race long tale indeed queer-looking party assembled bank-the birds draggled feathers, animals fur clinging close them, dripping wet, cross, uncomfortable.',
#  'first question course was, get dry again: consultation this, minutes seemed quite natural alice find herself talking familiarly them, she known her life.',
#  'indeed, she quite long argument lory, last turned sulky, would say, " older you, must know better;" alice would allow without knowing old was, and, lory positively refused tell age, said.',
#  'last mouse, seemed person authority among them, called out, "sit down, you, listen me!',
#  '\'ll soon make dry enough!"',
#  'sat once, large ring, mouse middle.',
#  'alice kept her eyes anxiously fixed it, she felt sure she would catch bad cold she get dry soon.',
#  '"ahem!"',
#  'said mouse important air, "are ready?',
#  'driest thing know.',
#  'silence round, please!',
#  "'william conqueror, whose cause favoured pope, soon submitted english, wanted leaders, late much accustomed usurpation conquest.",
#  'edwin morcar, earls mercia northumbria-\'" "ugh!"',
#  'said lory, shiver. "',
#  'beg pardon!"',
#  'said mouse, frowning, politely: "did speak?"',
#  '"not !"',
#  'said lory hastily. "',
#  'thought did," said mouse.',
#  '"- proceed.',
#  '\'edwin morcar, earls mercia northumbria, declared him: even stigand, patriotic archbishop canterbury, found advisable-\'" "found what?"',
#  'said duck.',
#  '"found it," mouse replied rather crossly: "of course know \'it\' means."',
#  '" know \'it\' means well enough,  find thing," said duck: "it\'s generally frog worm.',
#  'question is, archbishop find?"',
#  'mouse notice question, hurriedly went on, "\'-found advisable go edgar atheling meet william offer him crown.',
#  "william's conduct first moderate.",
#  'insolence his normans-\' getting now, dear?"',
#  'continued, turning alice spoke.',
#  '"as wet ever," said alice melancholy tone: "it seem dry all."',
#  '"in case," said dodo solemnly, rising feet, " move meeting adjourn, immediate adoption energetic remedies-" "speak english!"',
#  'said eaglet. "',
#  'know meaning half long words, and, what\'s more, believe either!"',
#  'eaglet bent head hide smile: birds tittered audibly.',
#  '"what going say," said dodo offended tone, "was, best thing get us dry would caucus-race."',
#  '"what is caucus-race?"',
#  'said alice; she wanted much know, dodo paused thought somebody ought speak, one else seemed inclined say anything.',
#  '"why," said dodo, "the best way explain it."',
#  '(and, might like try thing yourself, winter day, tell dodo managed it.)',
#  'first marked race-course, sort circle, ("the exact shape matter," said,) party placed along course, there.',
#  '"one, two, three, away," began running liked, left liked, easy know race over.',
#  'however, running half hour so, quite dry again, dodo suddenly called "the race over!"',
#  'crowded round it, panting, asking, "but won?"',
#  'question dodo could answer without great deal thought, sat long time one finger pressed upon forehead (the position usually see shakespeare, pictures him), rest waited silence.',
#  'last dodo said, "everybody won, must prizes."',
#  '"but give prizes?"',
#  'quite chorus voices asked.',
#  '"why, she, course," said dodo, pointing alice one finger; whole party crowded round her, calling confused way, "prizes!',
#  'prizes!"',
#  'alice idea do, despair she put her hand her pocket, pulled box comfits, (luckily salt water got it), handed round prizes.',
#  'exactly one a-piece, round.',
#  '"but she must prize herself, know," said mouse.',
#  '"of course," dodo replied gravely.',
#  '"what else got pocket?"',
#  'he went on, turning alice.',
#  '"only thimble," said alice sadly.',
#  '"hand here," said dodo.',
#  'crowded round her more, dodo solemnly presented thimble, saying "we beg acceptance elegant thimble;" and, finished short speech, cheered.',
#  'alice thought whole thing absurd, looked grave she dare laugh; and, she could think anything say, she simply bowed, took thimble, looking solemn she could.',
#  'next thing eat comfits: caused noise confusion, large birds complained could taste theirs, small ones choked patted back.',
#  'however, last, sat ring, begged mouse tell something more.',
#  '"you promised tell history, know," said alice, "and hate- ," she added whisper, half afraid would offended again.',
#  '"mine long sad tale!"',
#  'said mouse, turning alice, sighing.',
#  '"it is long tail, certainly," said alice, looking wonder mouse\'s tail; "but call sad?"',
#  'she kept puzzling mouse speaking, her idea tale something like this:- "fury said mouse, he met house, \'let us go law:  prosecute you.-come, \'ll take denial; must trial: really morning \'ve nothing do.\'',
#  "said mouse cur, 'such trial, dear sir, jury judge, would wasting breath.'",
#  '\'\'ll judge, \'ll jury,\' said cunning old fury: \'\'ll try whole cause, condemn death.\'"',
#  '"you attending!"',
#  'said mouse alice severely.',
#  '"what thinking of?"',
#  '" beg pardon," said alice humbly: "you got fifth bend, think?"',
#  '" not!"',
#  'cried mouse, sharply angrily.',
#  '"a knot!"',
#  'said alice, always ready make herself useful, looking anxiously her.',
#  '"oh, let help undo it!"',
#  '" shall nothing sort," said mouse, getting walking away.',
#  '"you insult talking nonsense!"',
#  '" mean it!"',
#  'pleaded poor alice.',
#  '"but easily offended, know!"',
#  'mouse growled reply.',
#  '"please come back finish story!"',
#  'alice called it; others joined chorus, "yes, please do!"',
#  'mouse shook head impatiently, walked little quicker.',
#  '"what pity stay!"',
#  'sighed lory, soon quite sight; old crab took opportunity saying her daughter "ah, dear!',
#  'let lesson never lose your temper!"',
#  '"hold tongue, ma!"',
#  'said young crab, little snappishly.',
#  '"you\'re enough try patience oyster!"',
#  '" wish dinah here, know do!"',
#  'said alice aloud, addressing nobody particular.',
#  '"she\' soon fetch back!"',
#  '"and dinah, might venture ask question?"',
#  'said lory.',
#  'alice replied eagerly, she always ready talk her pet: "dinah\'s cat.',
#  "she's capital one catching mice can't think!",
#  'oh, wish could see her birds!',
#  'why, she\'ll eat little bird soon look it!"',
#  'speech caused remarkable sensation among party.',
#  'birds hurried once: one old magpie began wrapping carefully, remarking, " really must getting home; night-air suit throat!"',
#  'canary called trembling voice children, "come away, dears!',
#  'high time bed!"',
#  'various pretexts moved off, alice soon left alone. "',
#  'wish mentioned dinah!"',
#  'she said herself melancholy tone.',
#  '"nobody seems like her, here, \' sure she\'s best cat world!',
#  'oh, dear dinah!',
#  'wonder shall ever see more!"',
#  'poor alice began cry again, she felt lonely low-spirited.',
#  'little while, however, she heard little pattering footsteps distance, she looked eagerly, half hoping mouse changed his mind, coming back finish his story.',
#  'rabbit sends little bill white rabbit, trotting slowly back again, looking anxiously went, lost something; she heard muttering "the duchess!',
#  'duchess!',
#  'oh dear paws!',
#  'oh fur whiskers!',
#  "she'll get executed, sure ferrets ferrets!",
#  'can dropped them, wonder?"',
#  'alice guessed moment looking fan pair white kid gloves, she good-naturedly began hunting them, nowhere seen-everything seemed changed since her swim pool, great hall, glass table little door, vanished completely.',
#  'soon rabbit noticed alice, she went hunting about, called her angry tone, "why, mary ann, are here?',
#  'run home moment, fetch pair gloves fan!',
#  'quick, now!"',
#  'alice much frightened she ran direction pointed to, without trying explain mistake made.',
#  '"he took his housemaid," she said herself she ran.',
#  '"how surprised he\'ll he finds am! \'',
#  'better take him his fan gloves-that is, find them."',
#  'she said this, she came upon neat little house, door bright brass plate name "w. rabbit," engraved upon it.',
#  'she went without knocking, hurried upstairs, great fear lest she meet real mary ann, turned house she found fan gloves.',
#  '"how queer seems," alice said herself, "to going messages rabbit!',
#  'suppose dinah\'ll sending messages next!"',
#  'she began fancying sort thing would happen: "\'miss alice!',
#  "come directly, get ready walk!'",
#  "'coming minute, nurse!",
#  "'ve got see mouse get out.'",
#  'think," alice went on, "that they\' let dinah stop house began ordering people like that!"',
#  'time she found her way tidy little room table window, (as she hoped) fan two three pairs tiny white kid gloves: she took fan pair gloves, going leave room, her eye fell upon little bottle stood near looking-glass.',
#  'label time words "drink me," nevertheless she uncorked put her lips. "',
#  'know something interesting sure happen," she said herself, "whenever eat drink anything; \'ll see bottle does.',
#  'hope it\'ll make grow large again, really \' quite tired tiny little thing!"',
#  'indeed, much sooner she expected: she drunk half bottle, she found her head pressing ceiling, stoop save her neck broken.',
#  'she hastily put bottle, saying herself "that\'s quite enough- hope grow more-as is, can\'t get door- wish drunk quite much!"',
#  'alas!',
#  'late wish that!',
#  'she went growing, growing, soon kneel floor: another minute even room this, she tried effect lying one elbow door, arm curled round her head.',
#  'still she went growing, and, last resource, she put one arm window, one foot chimney, said herself "now more, whatever happens.',
#  'will become me?"',
#  'luckily alice, little magic bottle full effect, she grew larger: still uncomfortable, and, seemed sort chance her ever getting room again, wonder she felt unhappy.',
#  '"it much pleasanter home," thought poor alice, "when one always growing larger smaller, ordered mice rabbits.',
#  "almost wish gone rabbit-hole-and yet-and yet-it's rather curious, know, sort life!",
#  'wonder can happened me!',
#  'used read fairy-tales, fancied kind thing never happened, middle one!',
#  'ought book written me, ought!',
#  'grow up, \'ll write one-but \' grown now," she added sorrowful tone; "at least there\'s room grow here."',
#  '"but then," thought alice, "shall never get older now?',
#  'comfort, one way-never old woman-but then-always lessons learn!',
#  'oh, like that!"',
#  '"oh, foolish alice!"',
#  'she answered herself.',
#  '"how learn lessons here?',
#  'why, there\'s hardly room you, room lesson-books!"',
#  'she went on, taking first one side other, making quite conversation altogether; minutes she heard voice outside, stopped listen.',
#  '"mary ann!',
#  'mary ann!"',
#  'said voice.',
#  '"fetch gloves moment!"',
#  'came little pattering feet stairs.',
#  'alice knew rabbit coming look her, she trembled till she shook house, quite forgetting she thousand times large rabbit, reason afraid it.',
#  "presently rabbit came door, tried open it; but, door opened inwards, alice's elbow pressed hard it, attempt proved failure.",
#  'alice heard say "then \'ll go round get window."',
#  '"that won\'t!"',
#  'thought alice, and, waiting till she fancied she heard rabbit window, she suddenly spread her hand, made snatch air.',
#  'she get hold anything, she heard little shriek fall, crash broken glass, she concluded possible fallen cucumber-frame, something sort.',
#  'next came angry voice-the rabbit\'s-"pat!',
#  'pat!',
#  'you?"',
#  'voice she never heard before, "sure \' here!',
#  'digging apples, yer honour!"',
#  '"digging apples, indeed!"',
#  'said rabbit angrily.',
#  '"here!',
#  'come help this!"',
#  '(sounds broken glass.)',
#  '"now tell me, pat, what\'s window?"',
#  '"sure, arm, yer honour!"',
#  '(he pronounced "arrum.")',
#  '"an arm, goose!',
#  'ever saw one size?',
#  'why, fills whole window!"',
#  '"sure, does, yer honour: arm that."',
#  '"well, got business there, rate: go take away!"',
#  'long silence this, alice could hear whispers then; as, "sure, like it, yer honour, all, all!"',
#  '"do tell you, coward!"',
#  'last she spread her hand again, made another snatch air.',
#  'time two little shrieks, sounds broken glass.',
#  '"what number cucumber-frames must be!"',
#  'thought alice. "',
#  "wonder they'll next!",
#  "pulling window, wish could! '",
#  'sure  want stay longer!"',
#  'she waited time without hearing anything more: last came rumbling little cartwheels, sound good many voices talking together: she made words: "where\'s ladder?-why, bring one; bill\'s got other-bill!',
#  "fetch here, lad!-here, put 'em corner-no, tie 'em together first-they reach half high enough yet-oh!",
#  "they'll well enough; particular-here, bill!",
#  'catch hold rope-will roof bear?-mind loose slate-oh, coming down!',
#  'heads below!"',
#  '(a loud crash)-"now, that?-it bill, fancy-who\'s go chimney?-nay,  shan\'t!',
#  "you it!-that won't, then!-bill's go down-here, bill!",
#  'master says go chimney!"',
#  '"oh!',
#  'bill\'s got come chimney, he?"',
#  'said alice herself.',
#  '"shy, seem put everything upon bill!',
#  'bill\'s place good deal: fireplace narrow, sure; think kick little!"',
#  'she drew her foot far chimney she could, waited till she heard little animal (she guess sort was) scratching scrambling chimney close her: then, saying herself "this bill," she gave one sharp kick, waited see would happen next.',
#  'first thing she heard general chorus "there goes bill!"',
#  'rabbit\'s voice along-"catch him, hedge!"',
#  'silence, another confusion voices-"hold his head-brandy now-don\'t choke him-how it, old fellow?',
#  'happened you?',
#  'tell us it!"',
#  'last came little feeble, squeaking voice, ("that\'s bill," thought alice,) "well, hardly know-no more, thank ye; \' better now-but \' deal flustered tell you-all know is, something comes like jack-in-the-box, goes like sky-rocket!"',
#  '"so did, old fellow!"',
#  'said others.',
#  '"we must burn house down!"',
#  'said rabbit\'s voice; alice called loud she could, "if do, \'ll set dinah you!"',
#  'dead silence instantly, alice thought herself, " wonder will next!',
#  'sense, they\' take roof off."',
#  'minute two, began moving again, alice heard rabbit say, "a barrowful do, begin with."',
#  '"a barrowful what?"',
#  'thought alice; she long doubt, next moment shower little pebbles came rattling window, hit her face.',
#  '"\'ll put stop this," she said herself, shouted out, "you\' better again!"',
#  'produced another dead silence.',
#  'alice noticed surprise pebbles turning little cakes lay floor, bright idea came her head.',
#  '"if eat one cakes," she thought, "it\'s sure make some change size; can\'t possibly make larger, must make smaller, suppose."',
#  'she swallowed one cakes, delighted find she began shrinking directly.',
#  'soon she small enough get door, she ran house, found quite crowd little animals birds waiting outside.',
#  'poor little lizard, bill, middle, held two guinea-pigs, giving something bottle.',
#  'made rush alice moment she appeared; she ran hard she could, soon found herself safe thick wood.',
#  '"the first thing \'ve got do," said alice herself, she wandered wood, "is grow right size again; second thing find way lovely garden.',
#  'think best plan."',
#  'sounded excellent plan, doubt, neatly simply arranged; difficulty was, she smallest idea set it; she peering anxiously among trees, little sharp bark her head made her look great hurry.',
#  'enormous puppy looking her large round eyes, feebly stretching one paw, trying touch her.',
#  '"poor little thing!"',
#  'said alice, coaxing tone, she tried hard whistle it; she terribly frightened time thought might hungry, case would likely eat her spite her coaxing.',
#  'hardly knowing she did, she picked little bit stick, held puppy; whereupon puppy jumped air feet once, yelp delight, rushed stick, made believe worry it; alice dodged behind great thistle, keep herself run over; moment she appeared side, puppy made another rush stick, tumbled head heels hurry get hold it; alice, thinking like game play cart-horse, expecting every moment trampled feet, ran round thistle again; puppy began series short charges stick, running little way forwards time long way back, barking hoarsely while, till last sat good way off, panting, tongue hanging mouth, great eyes half shut.',
#  "seemed alice good opportunity making her escape; she set once, ran till she quite tired breath, till puppy's bark sounded quite faint distance.",
#  '"and yet dear little puppy was!"',
#  'said alice, she leant buttercup rest herself, fanned herself one leaves: " liked teaching tricks much, if-if \' right size it!',
#  "oh dear! '",
#  "nearly forgotten 've got grow again!",
#  'let see-how is managed?',
#  'suppose ought eat drink something other; great question is, what?"',
#  'great question certainly was, what?',
#  'alice looked round her flowers blades grass, she see anything looked like right thing eat drink circumstances.',
#  'large mushroom growing near her, height herself; she looked it, sides it, behind it, occurred her she might well look see top it.',
#  'she stretched herself tiptoe, peeped edge mushroom, her eyes immediately met large blue caterpillar, sitting top arms folded, quietly smoking long hookah, taking smallest notice her anything else.',
#  'advice caterpillar caterpillar alice looked time silence: last caterpillar took hookah mouth, addressed her languid, sleepy voice.',
#  '"who you?"',
#  'said caterpillar.',
#  'encouraging opening conversation.',
#  'alice replied, rather shyly, "- hardly know, sir, present-at least know was got morning, think must changed several times since then."',
#  '"what mean that?"',
#  'said caterpillar sternly.',
#  '"explain yourself!"',
#  '" can\'t explain myself, \' afraid, sir," said alice, "because \' myself, see."',
#  '" see," said caterpillar. "\'',
#  'afraid can\'t put clearly," alice replied politely, "for can\'t understand begin with; many different sizes day confusing."',
#  '"it isn\'t," said caterpillar.',
#  '"well, perhaps found yet," said alice; "but turn chrysalis-you day, know-and butterfly, think feel little queer, you?"',
#  '"not bit," said caterpillar.',
#  '"well, perhaps feelings may different," said alice; "all know is, would feel queer me."',
#  '"you!"',
#  'said caterpillar contemptuously.',
#  '"who you?"',
#  'brought back beginning conversation.',
#  'alice felt little irritated caterpillar\'s making very short remarks, she drew herself said, gravely, " think, ought tell you are, first."',
#  '"why?"',
#  'said caterpillar.',
#  'another puzzling question; alice could think good reason, caterpillar seemed very unpleasant state mind, she turned away.',
#  '"come back!"',
#  'caterpillar called her.',
#  '"\'ve something important say!"',
#  'sounded promising, certainly: alice turned came back again.',
#  '"keep temper," said caterpillar.',
#  '"is all?"',
#  'said alice, swallowing her anger well she could.',
#  '"no," said caterpillar.',
#  'alice thought she might well wait, she nothing else do, perhaps might tell her something worth hearing.',
#  'minutes puffed away without speaking, last unfolded arms, took hookah mouth again, said, "so think changed, you?"',
#  '"\' afraid am, sir," said alice; " can\'t remember things used-and keep size ten minutes together!"',
#  '"can\'t remember what things?"',
#  'said caterpillar.',
#  '"well, \'ve tried say "how doth little busy bee," came different!"',
#  'alice replied melancholy voice.',
#  '"repeat, "you old, father william,\'" said caterpillar.',
#  'alice folded her hands, began:- "you old, father william," young man said, "and hair become white; yet incessantly stand head- think, age, right?"',
#  '"in youth," father william replied his son, " feared might injure brain; but, \' perfectly sure none, why, again."',
#  '"you old," said youth, "as mentioned before, grown uncommonly fat; yet turned back-somersault door- pray, reason that?"',
#  '"in youth," said sage, he shook his grey locks, " kept limbs supple use ointment-one shilling box- allow sell couple?"',
#  '"you old," said youth, "and jaws weak anything tougher suet; yet finished goose, bones beak- pray, manage it?"',
#  '"in youth," said his father, " took law, argued case wife; muscular strength, gave jaw, lasted rest life."',
#  '"you old," said youth, "one would hardly suppose eye steady ever; yet balanced eel end nose- made awfully clever?"',
#  '" answered three questions, enough," said his father; "don\'t give airs!',
#  'think listen day stuff?',
#  'off, \'ll kick stairs!"',
#  '"that said right," said caterpillar.',
#  '"not quite right, \' afraid," said alice, timidly; "some words got altered."',
#  '"it wrong beginning end," said caterpillar decidedly, silence minutes.',
#  'caterpillar first speak.',
#  '"what size want be?"',
#  'asked.',
#  '"oh, \' particular size," alice hastily replied; "only one like changing often, know."',
#  '" don\'t know," said caterpillar.',
#  'alice said nothing: she never much contradicted her life before, she felt she losing her temper.',
#  '"are content now?"',
#  'said caterpillar.',
#  '"well, like little larger, sir, mind," said alice: "three inches wretched height be."',
#  '"it good height indeed!"',
#  'said caterpillar angrily, rearing upright spoke (it exactly three inches high).',
#  '"but \' used it!"',
#  'pleaded poor alice piteous tone.',
#  'she thought herself, " wish creatures easily offended!"',
#  '"you\'ll get used time," said caterpillar; put hookah mouth began smoking again.',
#  'time alice waited patiently chose speak again.',
#  'minute two caterpillar took hookah mouth yawned twice, shook itself.',
#  'got mushroom, crawled away grass, merely remarking went, "one side make grow taller, side make grow shorter."',
#  '"one side what?',
#  'side what?"',
#  'thought alice herself.',
#  '"of mushroom," said caterpillar, she asked aloud; another moment sight.',
#  'alice remained looking thoughtfully mushroom minute, trying make two sides it; perfectly round, she found difficult question.',
#  'however, last she stretched her arms round far would go, broke bit edge hand.',
#  '"and which?"',
#  'she said herself, nibbled little right-hand bit try effect: next moment she felt violent blow underneath her chin: struck her foot!',
#  'she good deal frightened sudden change, she felt time lost, she shrinking rapidly; she set work eat bit.',
#  'her chin pressed closely her foot, hardly room open her mouth; she last, managed swallow morsel lefthand bit.',
#  '"come, head\'s free last!"',
#  'said alice tone delight, changed alarm another moment, she found her shoulders nowhere found: she could see, she looked down, immense length neck, seemed rise like stalk sea green leaves lay far her.',
#  '"what can green stuff be?"',
#  'said alice.',
#  '"and have shoulders got to?',
#  'oh, poor hands, can\'t see you?"',
#  'she moving she spoke, result seemed follow, except little shaking among distant green leaves.',
#  'seemed chance getting her hands her head, she tried get her head them, delighted find her neck would bend easily direction, like serpent.',
#  'she succeeded curving graceful zigzag, going dive among leaves, she found nothing tops trees she wandering, sharp hiss made her draw back hurry: large pigeon flown her face, beating her violently wings.',
#  '"serpent!"',
#  'screamed pigeon. "\'',
#  'not serpent!"',
#  'said alice indignantly.',
#  '"let alone!"',
#  '"serpent, say again!"',
#  'repeated pigeon, subdued tone, added kind sob, "\'ve tried every way, nothing seems suit them!"',
#  '" least idea talking about," said alice.',
#  '"\'ve tried roots trees, \'ve tried banks, \'ve tried hedges," pigeon went on, without attending her; "but serpents!',
#  'there\'s pleasing them!"',
#  'alice puzzled, she thought use saying anything till pigeon finished.',
#  '"as trouble enough hatching eggs," said pigeon; "but must look-out serpents night day!',
#  'why, wink sleep three weeks!"',
#  '"\' sorry annoyed," said alice, beginning see meaning.',
#  '"and \' taken highest tree wood," continued pigeon, raising voice shriek, "and thinking free last, must needs come wriggling sky!',
#  'ugh, serpent!"',
#  '"but \' not serpent, tell you!"',
#  'said alice. "\'',
#  'a-\' a-" "well!',
#  'what you?"',
#  'said pigeon. "',
#  'see trying invent something!"',
#  '"-\' little girl," said alice, rather doubtfully, she remembered number changes she gone day.',
#  '"a likely story indeed!"',
#  'said pigeon tone deepest contempt.',
#  '"\'ve seen good many little girls time, never one neck that!',
#  'no, no!',
#  "serpent; there's use denying it.",
#  'suppose telling next never tasted egg!"',
#  '" have tasted eggs, certainly," said alice, truthful child; "but little girls eat eggs quite much serpents do, know."',
#  '" believe it," said pigeon; "but do, they\'re kind serpent, that\'s say."',
#  'new idea alice, she quite silent minute two, gave pigeon opportunity adding, "you\'re looking eggs, know that well enough; matter whether little girl serpent?"',
#  '"it matters good deal me," said alice hastily; "but \' looking eggs, happens; was, want yours: like raw."',
#  '"well, off, then!"',
#  'said pigeon sulky tone, settled nest.',
#  'alice crouched among trees well she could, her neck kept getting entangled among branches, every she stop untwist it.',
#  'she remembered she still held pieces mushroom her hands, she set work carefully, nibbling first one other, growing sometimes taller sometimes shorter, she succeeded bringing herself her usual height.',
#  'long since she anything near right size, felt quite strange first; she got used minutes, began talking herself, usual.',
#  '"come, there\'s half plan done now!',
#  "puzzling changes are! '",
#  "never sure ' going be, one minute another!",
#  'however, \'ve got back right size: next thing is, get beautiful garden-how is done, wonder?"',
#  'she said this, she came suddenly upon open place, little house four feet high.',
#  '"whoever lives there," thought alice, "it\'ll never come upon this size: why, frighten wits!"',
#  'she began nibbling righthand bit again, venture go near house till she brought herself nine inches high.',
#  'pig pepper minute two she stood looking house, wondering next, suddenly footman livery came running wood-(she considered him footman he livery: otherwise, judging his face only, she would called him fish)-and rapped loudly door his knuckles.',
#  'opened another footman livery, round face, large eyes like frog; footmen, alice noticed, powdered hair curled heads.',
#  'she felt curious know about, crept little way wood listen.',
#  'fish-footman began producing his arm great letter, nearly large himself, he handed other, saying, solemn tone, "for duchess.',
#  'invitation queen play croquet."',
#  'frog-footman repeated, solemn tone, changing order words little, "from queen.',
#  'invitation duchess play croquet."',
#  'bowed low, curls got entangled together.',
#  'alice laughed much this, she run back wood fear hearing her; she next peeped fish-footman gone, sitting ground near door, staring stupidly sky.',
#  'alice went timidly door, knocked.',
#  '"there\'s sort use knocking," said footman, "and two reasons.',
#  'first, \' side door are; secondly, they\'re making noise inside, one could possibly hear you."',
#  'certainly was extraordinary noise going within-a constant howling sneezing, every great crash, dish kettle broken pieces.',
#  '"please, then," said alice, "how get in?"',
#  '"there might sense knocking," footman went without attending her, "if door us.',
#  'instance, inside, might knock, could let out, know."',
#  'he looking sky time he speaking, alice thought decidedly uncivil.',
#  '"but perhaps he can\'t help it," she said herself; "his eyes very nearly top his head.',
#  'rate he might answer questions.-how get in?"',
#  'she repeated, aloud. "',
#  'shall sit here," footman remarked, "till tomorrow-" moment door house opened, large plate came skimming out, straight footman\'s head: grazed his nose, broke pieces one trees behind him.',
#  '"-or next day, maybe," footman continued tone, exactly nothing happened.',
#  '"how get in?"',
#  'asked alice again, louder tone.',
#  '"are get all?"',
#  'said footman.',
#  '"that\'s first question, know."',
#  'was, doubt: alice like told so.',
#  '"it\'s really dreadful," she muttered herself, "the way creatures argue.',
#  'enough drive one crazy!"',
#  'footman seemed think good opportunity repeating his remark, variations. "',
#  'shall sit here," he said, "on off, days days."',
#  '"but  do?"',
#  'said alice.',
#  '"anything like," said footman, began whistling.',
#  '"oh, there\'s use talking him," said alice desperately: "he\'s perfectly idiotic!"',
#  'she opened door went in.',
#  'door led right large kitchen, full smoke one end other: duchess sitting three-legged stool middle, nursing baby; cook leaning fire, stirring large cauldron seemed full soup.',
#  '"there\'s certainly much pepper soup!"',
#  'alice said herself, well she could sneezing.',
#  'certainly much air.',
#  "even duchess sneezed occasionally; baby, sneezing howling alternately without moment's pause.",
#  'things kitchen sneeze, cook, large cat sitting hearth grinning ear ear.',
#  '"please would tell me," said alice, little timidly, she quite sure whether good manners her speak first, "why cat grins like that?"',
#  '"it\'s cheshire cat," said duchess, "and that\'s why.',
#  'pig!"',
#  'she said last word sudden violence alice quite jumped; she saw another moment addressed baby, her, she took courage, went again:- " know cheshire cats always grinned; fact, know cats could grin."',
#  '"they can," said duchess; "and \'em do."',
#  '" know do," alice said politely, feeling quite pleased got conversation.',
#  '"you know much," said duchess; "and that\'s fact."',
#  'alice like tone remark, thought would well introduce subject conversation.',
#  'she trying fix one, cook took cauldron soup fire, set work throwing everything within her reach duchess baby-the fire-irons came first; followed shower saucepans, plates, dishes.',
#  'duchess took notice even hit her; baby howling much already, quite impossible say whether blows hurt not.',
#  '"oh, please mind doing!"',
#  'cried alice, jumping agony terror.',
#  '"oh, goes his precious nose!"',
#  'unusually large saucepan flew close it, nearly carried off.',
#  '"if everybody minded business," duchess said hoarse growl, "the world would go round deal faster does."',
#  '"which would not advantage," said alice, felt glad get opportunity showing little her knowledge.',
#  '"just think work would make day night!',
#  'see earth takes twenty-four hours turn round axis-" "talking axes," said duchess, "chop her head!"',
#  'alice glanced rather anxiously cook, see she meant take hint; cook busily stirring soup, seemed listening, she went again: "twenty-four hours, think; twelve?',
#  '-" "oh, bother me," said duchess; " never could abide figures!"',
#  'she began nursing her child again, singing sort lullaby she so, giving violent shake end every line: "speak roughly little boy, beat him he sneezes: he annoy, he knows teases."',
#  'chorus.',
#  '(in cook baby joined): "wow!',
#  'wow!',
#  'wow!"',
#  'duchess sang second verse song, she kept tossing baby violently down, poor little thing howled so, alice could hardly hear words:- " speak severely boy, beat him he sneezes; he thoroughly enjoy pepper he pleases!"',
#  'chorus.',
#  '"wow!',
#  'wow!',
#  'wow!"',
#  '"here!',
#  'may nurse bit, like!"',
#  'duchess said alice, flinging baby her she spoke. "',
#  'must go get ready play croquet queen," she hurried room.',
#  'cook threw frying-pan her she went out, missed her.',
#  'alice caught baby difficulty, queer-shaped little creature, held arms legs directions, "just like star-fish," thought alice.',
#  'poor little thing snorting like steam-engine she caught it, kept doubling straightening again, altogether, first minute two, much she could hold it.',
#  'soon she made proper way nursing it, (which twist sort knot, keep tight hold right ear left foot, prevent undoing itself,) she carried open air.',
#  '"if take child away me," thought alice, "they\'re sure kill day two: murder leave behind?"',
#  'she said last words loud, little thing grunted reply (it left sneezing time).',
# ...
#  'therefore \' mad."',
#  '" call purring, growling," said alice.',
#  '"call like," said cat.',
#  '"do play croquet queen to-day?"',
#  '" like much," said alice, "but invited yet."',
#  '"you\'ll see there," said cat, vanished.',
#  'alice much surprised this, she getting used queer things happening.',
#  'she looking place been, suddenly appeared again.',
#  '"by-the-bye, became baby?"',
#  'said cat. "\'',
#  'nearly forgotten ask."',
#  '"it turned pig," alice quietly said, come back natural way. "',
#  'thought would," said cat, vanished again.',
#  'alice waited little, half expecting see again, appear, minute two she walked direction march hare said live.',
#  '"\'ve seen hatters before," she said herself; "the march hare much interesting, perhaps may raving mad-at least mad march."',
#  'she said this, she looked up, cat again, sitting branch tree.',
#  '"did say pig, fig?"',
#  'said cat. "',
#  'said pig," replied alice; "and wish keep appearing vanishing suddenly: make one quite giddy."',
#  '"all right," said cat; time vanished quite slowly, beginning end tail, ending grin, remained time rest gone.',
#  '"well!',
#  '\'ve often seen cat without grin," thought alice; "but grin without cat!',
#  'curious thing ever saw life!"',
#  'she gone much farther she came sight house march hare: she thought must right house, chimneys shaped like ears roof thatched fur.',
#  'large house, she like go nearer till she nibbled lefthand bit mushroom, raised herself two feet high: even she walked towards rather timidly, saying herself "suppose raving mad all!',
#  'almost wish \' gone see hatter instead!"',
#  'mad tea-party table set tree front house, march hare hatter tea it: dormouse sitting them, fast asleep, two using cushion, resting elbows it, talking head.',
#  '"very uncomfortable dormouse," thought alice; "only, asleep, suppose mind."',
#  'table large one, three crowded together one corner it: "no room!',
#  'room!"',
#  'cried saw alice coming.',
#  '"there\'s plenty room!"',
#  'said alice indignantly, she sat large arm-chair one end table.',
#  '"have wine," march hare said encouraging tone.',
#  'alice looked round table, nothing tea. "',
#  'see wine," she remarked.',
#  '"there any," said march hare.',
#  '"then civil offer it," said alice angrily.',
#  '"it civil sit without invited," said march hare. "',
#  'know your table," said alice; "it\'s laid great many three."',
#  '"your hair wants cutting," said hatter.',
#  'he looking alice time great curiosity, his first speech.',
#  '"you learn make personal remarks," alice said severity; "it\'s rude."',
#  'hatter opened his eyes wide hearing this; he said was, "why raven like writing-desk?"',
#  '"come, shall fun now!"',
#  'thought alice. "\'',
#  'glad they\'ve begun asking riddles.- believe guess that," she added aloud.',
#  '"do mean think find answer it?"',
#  'said march hare.',
#  '"exactly so," said alice.',
#  '"then say mean," march hare went on. "',
#  'do," alice hastily replied; "at least-at least mean say-that\'s thing, know."',
#  '"not thing bit!"',
#  'said hatter.',
#  '"you might well say \' see eat\' thing \' eat see\'!"',
#  '"you might well say," added march hare, "that \' like get\' thing \' get like\'!"',
#  '"you might well say," added dormouse, seemed talking his sleep, "that \' breathe sleep\' thing \' sleep breathe\'!"',
#  '"it is thing you," said hatter, conversation dropped, party sat silent minute, alice thought she could remember ravens writing-desks, much.',
#  'hatter first break silence.',
#  '"what day month it?"',
#  'he said, turning alice: he taken his watch his pocket, looking uneasily, shaking every then, holding his ear.',
#  'alice considered little, said "the fourth."',
#  '"two days wrong!"',
#  'sighed hatter. "',
#  'told butter suit works!"',
#  'he added looking angrily march hare.',
#  '"it best butter," march hare meekly replied.',
#  '"yes, crumbs must got well," hatter grumbled: "you put bread-knife."',
#  'march hare took watch looked gloomily: he dipped his cup tea, looked again: he could think nothing better say his first remark, "it best butter, know."',
#  'alice looking his shoulder curiosity.',
#  '"what funny watch!"',
#  'she remarked.',
#  '"it tells day month, tell o\'clock is!"',
#  '"why it?"',
#  'muttered hatter.',
#  '"does your watch tell year is?"',
#  '"of course not," alice replied readily: "but that\'s stays year long time together."',
#  '"which case mine," said hatter.',
#  'alice felt dreadfully puzzled.',
#  'hatter\'s remark seemed sort meaning it, yet certainly english. "',
#  'quite understand you," she said, politely she could.',
#  '"the dormouse asleep again," said hatter, he poured little hot tea upon nose.',
#  'dormouse shook head impatiently, said, without opening eyes, "of course, course; going remark myself."',
#  '"have guessed riddle yet?"',
#  'hatter said, turning alice again.',
#  '"no, give up," alice replied: "what\'s answer?"',
#  '" slightest idea," said hatter.',
#  '"nor ," said march hare.',
#  'alice sighed wearily. "',
#  'think might something better time," she said, "than waste asking riddles answers."',
#  '"if knew time well do," said hatter, "you talk wasting it.',
#  'him."',
#  '" know mean," said alice.',
#  '"of course don\'t!"',
#  'hatter said, tossing his head contemptuously. "',
#  'dare say never even spoke time!"',
#  '"perhaps not," alice cautiously replied: "but know beat time learn music."',
#  '"ah!',
#  'accounts it," said hatter.',
#  '"he stand beating.',
#  "now, kept good terms him, he' almost anything liked clock.",
#  "instance, suppose nine o'clock morning, time begin lessons: whisper hint time, round goes clock twinkling!",
#  'half-past one, time dinner!"',
#  '(" wish was," march hare said whisper.)',
#  '"that would grand, certainly," said alice thoughtfully: "but then- hungry it, know."',
#  '"not first, perhaps," said hatter: "but could keep half-past one long liked."',
#  '"is way you manage?"',
#  'alice asked.',
#  'hatter shook his head mournfully.',
#  '"not !"',
#  'he replied.',
#  '"we quarrelled last march-just he went mad, know-" (pointing his tea spoon march hare,) "-it great concert given queen hearts, sing \'twinkle, twinkle, little bat!',
#  "wonder at!'",
#  'know song, perhaps?"',
#  '"\'ve heard something like it," said alice.',
#  '"it goes on, know," hatter continued, "in way:- \'up world fly, like tea-tray sky.',
#  'twinkle, twinkle-\'" dormouse shook itself, began singing sleep "twinkle, twinkle, twinkle, twinkle-" went long pinch make stop.',
#  '"well, \' hardly finished first verse," said hatter, "when queen jumped bawled out, \'he\'s murdering time!',
#  'his head!\'"',
#  '"how dreadfully savage!"',
#  'exclaimed alice.',
#  '"and ever since that," hatter went mournful tone, "he thing ask!',
#  'always six o\'clock now."',
#  "bright idea came alice's head.",
#  '"is reason many tea-things put here?"',
#  'she asked.',
#  '"yes, that\'s it," said hatter sigh: "it\'s always tea-time, we\'ve time wash things whiles."',
#  '"then keep moving round, suppose?"',
#  'said alice.',
#  '"exactly so," said hatter: "as things get used up."',
#  '"but happens come beginning again?"',
#  'alice ventured ask.',
#  '"suppose change subject," march hare interrupted, yawning. "\'',
#  'getting tired this.',
#  'vote young lady tells us story."',
#  '"\' afraid know one," said alice, rather alarmed proposal.',
#  '"then dormouse shall!"',
#  'cried.',
#  '"wake up, dormouse!"',
#  'pinched sides once.',
#  'dormouse slowly opened his eyes. "',
#  'asleep," he said hoarse, feeble voice: " heard every word fellows saying."',
#  '"tell us story!"',
#  'said march hare.',
#  '"yes, please do!"',
#  'pleaded alice.',
#  '"and quick it," added hatter, "or asleep done."',
#  '"once upon time three little sisters," dormouse began great hurry; "and names elsie, lacie, tillie; lived bottom well-" "what live on?"',
#  'said alice, always took great interest questions eating drinking.',
#  '"they lived treacle," said dormouse, thinking minute two.',
#  '"they done that, know," alice gently remarked; "they\' ill." "so were," said dormouse; "very ill." alice tried fancy herself extraordinary ways living would like, puzzled her much, she went on: "but live bottom well?"',
#  '"take tea," march hare said alice, earnestly.',
#  '"\'ve nothing yet," alice replied offended tone, "so can\'t take more."',
#  '"you mean can\'t take less," said hatter: "it\'s easy take more nothing."',
#  '"nobody asked your opinion," said alice.',
#  '"who\'s making personal remarks now?"',
#  'hatter asked triumphantly.',
#  'alice quite know say this: she helped herself tea bread-and-butter, turned dormouse, repeated her question.',
#  '"why live bottom well?"',
#  'dormouse took minute two think it, said, "it treacle-well."',
#  '"there\'s thing!"',
#  'alice beginning angrily, hatter march hare went "sh!',
#  'sh!"',
#  'dormouse sulkily remarked, "if can\'t civil, better finish story yourself."',
#  '"no, please go on!"',
#  'alice said humbly; " interrupt again.',
#  'dare say may one."',
#  '"one, indeed!"',
#  'said dormouse indignantly.',
#  'however, he consented go on.',
#  '"and three little sisters-they learning draw, know-" "what draw?"',
#  'said alice, quite forgetting her promise.',
#  '"treacle," said dormouse, without considering time. "',
#  'want clean cup," interrupted hatter: "let\'s move one place on."',
#  "he moved he spoke, dormouse followed him: march hare moved dormouse's place, alice rather unwillingly took place march hare.",
#  'hatter one got advantage change: alice good deal worse before, march hare upset milk-jug his plate.',
#  'alice wish offend dormouse again, she began cautiously: "but understand.',
#  'draw treacle from?"',
#  '"you draw water water-well," said hatter; "so think could draw treacle treacle-well-eh, stupid?"',
#  '"but in well," alice said dormouse, choosing notice last remark.',
#  '"of course were," said dormouse; "-well in."',
#  'answer confused poor alice, she let dormouse go time without interrupting it.',
#  '"they learning draw," dormouse went on, yawning rubbing eyes, getting sleepy; "and drew manner things-everything begins -" "why ?"',
#  'said alice.',
#  '"why not?"',
#  'said march hare.',
#  'alice silent.',
#  'dormouse closed eyes time, going doze; but, pinched hatter, woke little shriek, went on: "-that begins , mouse-traps, moon, memory, muchness-you know say things "much muchness"-did ever see thing drawing muchness?"',
#  '"really, ask me," said alice, much confused, " think-" "then talk," said hatter.',
#  'piece rudeness alice could bear: she got great disgust, walked off; dormouse fell asleep instantly, neither others took least notice her going, though she looked back twice, half hoping would call her: last time she saw them, trying put dormouse teapot.',
#  '"at rate \'ll never go there again!"',
#  'said alice she picked her way wood.',
#  '"it\'s stupidest tea-party ever life!"',
#  'she said this, she noticed one trees door leading right it.',
#  '"that\'s curious!"',
#  'she thought.',
#  '"but everything\'s curious today.',
#  'think may well go once."',
#  'she went.',
#  'she found herself long hall, close little glass table.',
#  '"now, \'ll manage better time," she said herself, began taking little golden key, unlocking door led garden.',
#  'she went work nibbling mushroom (she kept piece her pocket) till she foot high: she walked little passage: then-she found herself last beautiful garden, among bright flower-beds cool fountains.',
#  "queen's croquet-ground large rose-tree stood near entrance garden: roses growing white, three gardeners it, busily painting red.",
#  'alice thought curious thing, she went nearer watch them, she came she heard one say, "look now, five!',
#  'go splashing paint like that!"',
#  '" help it," said five, sulky tone; "seven jogged elbow."',
#  'seven looked said, "that\'s right, five!',
#  'always lay blame others!"',
#  '"you\' better talk!"',
#  'said five. "',
#  'heard queen say yesterday deserved beheaded!"',
#  '"what for?"',
#  'said one spoken first.',
#  '"that\'s none your business, two!"',
#  'said seven.',
#  '"yes, is his business!"',
#  'said five, "and \'ll tell him-it bringing cook tulip-roots instead onions."',
#  'seven flung his brush, begun "well, unjust things-" his eye chanced fall upon alice, she stood watching them, he checked himself suddenly: others looked round also, bowed low.',
#  '"would tell me," said alice, little timidly, "why painting roses?"',
#  'five seven said nothing, looked two.',
#  'two began low voice, "why fact is, see, miss, ought red rose-tree, put white one mistake; queen find out, heads cut off, know.',
#  'see, miss, we\'re best, afore she comes, to-" moment five, anxiously looking across garden, called "the queen!',
#  'queen!"',
#  'three gardeners instantly threw flat upon faces.',
#  'sound many footsteps, alice looked round, eager see queen.',
#  'first came ten soldiers carrying clubs; shaped like three gardeners, oblong flat, hands feet corners: next ten courtiers; ornamented diamonds, walked two two, soldiers did.',
#  'came royal children; ten them, little dears came jumping merrily along hand hand, couples: ornamented hearts.',
#  'next came guests, mostly kings queens, among alice recognised white rabbit: talking hurried nervous manner, smiling everything said, went without noticing her.',
#  "followed knave hearts, carrying king's crown crimson velvet cushion; and, last grand procession, came king queen hearts.",
#  'alice rather doubtful whether she ought lie her face like three gardeners, she could remember ever heard rule processions; "and besides, would use procession," thought she, "if people lie upon faces, see it?"',
#  'she stood still she was, waited.',
#  'procession came opposite alice, stopped looked her, queen said severely "who this?"',
#  'she said knave hearts, bowed smiled reply.',
#  '"idiot!"',
#  'said queen, tossing her head impatiently; and, turning alice, she went on, "what\'s name, child?"',
#  '"my name alice, please majesty," said alice politely; she added, herself, "why, they\'re pack cards, all.',
#  'afraid them!"',
#  '"and these?"',
#  'said queen, pointing three gardeners lying round rose-tree; for, see, lying faces, pattern backs rest pack, she could tell whether gardeners, soldiers, courtiers, three her children.',
#  '"how  know?"',
#  'said alice, surprised her courage.',
#  '"it\'s business mine."',
#  'queen turned crimson fury, and, glaring her moment like wild beast, screamed "off her head!',
#  'off-" "nonsense!"',
#  'said alice, loudly decidedly, queen silent.',
#  'king laid his hand upon her arm, timidly said "consider, dear: she child!"',
#  'queen turned angrily away him, said knave "turn over!"',
#  'knave so, carefully, one foot.',
#  '"get up!"',
#  'said queen, shrill, loud voice, three gardeners instantly jumped up, began bowing king, queen, royal children, everybody else.',
#  '"leave that!"',
#  'screamed queen.',
#  '"you make giddy."',
#  'then, turning rose-tree, she went on, "what have here?"',
#  '"may please majesty," said two, humble tone, going one knee he spoke, "we trying-" " see!"',
#  'said queen, meanwhile examining roses.',
#  '"off heads!"',
#  'procession moved on, three soldiers remaining behind execute unfortunate gardeners, ran alice protection.',
#  '"you beheaded!"',
#  'said alice, she put large flower-pot stood near.',
#  'three soldiers wandered minute two, looking them, quietly marched others.',
#  '"are heads off?"',
#  'shouted queen.',
#  '"their heads gone, please majesty!"',
#  'soldiers shouted reply.',
#  '"that\'s right!"',
#  'shouted queen.',
#  '"can play croquet?"',
#  'soldiers silent, looked alice, question evidently meant her.',
#  '"yes!"',
#  'shouted alice.',
#  '"come on, then!"',
#  'roared queen, alice joined procession, wondering much would happen next.',
#  '"it\'s-it\'s fine day!"',
#  'said timid voice her side.',
#  'she walking white rabbit, peeping anxiously her face.',
#  '"very," said alice: "-where\'s duchess?"',
#  '"hush!',
#  'hush!"',
#  'said rabbit low, hurried tone.',
#  'he looked anxiously his shoulder he spoke, raised himself upon tiptoe, put his mouth close her ear, whispered "she\'s sentence execution."',
#  '"what for?"',
#  'said alice.',
#  '"did say \'what pity!\'?"',
#  'rabbit asked.',
#  '"no, didn\'t," said alice: " think pity.',
#  ...]

# %%
os.getcwd()
# Out:
# '/Users/pazma/Documents/BSE/text_mining/term_project'

# %%
# import female and male character names lists
female_characters = open("female_character_names.txt", "r")
male_characters = open("male_character_names.txt", "r")
female_characters = female_characters.read().splitlines()
male_characters = male_characters.read().splitlines()

# %%
len(female_characters), female_characters[:3]
# Out:
# (1445, ['fulvia', 'gwen', 'marjie'])

# %%
from pandas.core.common import flatten
# token_new_author_list=list(flatten([w.split() for w in new_author_list]))
puncts=[")", "(", ",", ".", "?", "!", "[", "]", ";", "''","'s", "`", "'ve", "'re", "'ll",
       "ix", "x", "v", "i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "xi", "xii", 
       "xiii", "xiv", "xv", "xvi", "xvii", "xviii", "xix"]

# %%
# clean sentences
lemmatiser = WordNetLemmatizer()

clean_sentences_all=[]
for i in range(len(sentences)): 
    clean_sentences=[]
    for j in range(len(sentences[i])):
        #lemmatize
        lemm_sentence=[lemmatiser.lemmatize(token.lower(), pos='v') for token in nltk.word_tokenize(sentences[i][j])]
        lemm_sentence_clean=[]
        # remove stopwords
        for word in lemm_sentence:
            if word not in stopwords_wo_pronoun:
                lemm_sentence_clean.append(word)
       #  # remove authors' names
       #  lemm_sentence_clean2=[]
       #  for word in lemm_sentence_clean:
       #      if word not in token_new_author_list:
       #          lemm_sentence_clean2.append(word)
                
        # remove punctuations
        lemm_sentence_clean3=[]
        for word in lemm_sentence_clean:
            if word not in puncts:
                lemm_sentence_clean3.append(word)
        # POS tag and keep only nouns, verbs, adjectives and pronouns
        pos_=nltk.pos_tag(lemm_sentence_clean3)

        pos_=[s for s in pos_ if (s[1] == 'JJ')|
        (s[1] == "JJR")|
        (s[1] == "JJS")|      
        (s[1] == "VB" )|
        (s[1] == "VBD")|
        (s[1] == "VBG")|
        (s[1] == "VBN")|
        (s[1] == "VBP")|
        (s[1] == "VBZ")|
        (s[1] == "NN" )|
        (s[1] == "NNP")|
        (s[1] == "NNS")|
        (s[1] == "NNPS")|
             (s[1] == "PRP")|
             (s[1] == "PRP$")]

        lemm_sentence_clean3=[x[0] for x in pos_]
        # join back
        clean_sent=' '.join(lemm_sentence_clean3)
        clean_sentences.append(clean_sent)
    clean_sentences_all.append(clean_sentences)

# %%
clean_sentences_all[0]
# Out:
# ['illustration alice adventure wonderland lewis carroll millennium fulcrum edition content rabbit-hole pool caucus-race long tale rabbit send little bill advice caterpillar pig pepper mad tea-party queen croquet-ground',
#  'mock turtle story lobster quadrille steal tarts',
#  'alice evidence rabbit-hole alice begin get tire sit her sister bank nothing she peep book her sister read picture conversations use book think picture conversations',
#  'she consider her mind well she hot day make her feel sleepy stupid pleasure make daisy-chain worth trouble get pick daisies white rabbit pink eye run her',
#  'nothing remarkable alice think much way hear rabbit say oh dear',
#  'dear',
#  'late',
#  'she think afterwards occur her she wonder time seem natural rabbit take watch waistcoat-pocket look hurry start her feet flash her mind she see rabbit waistcoat-pocket watch take burn curiosity she run field time see pop large rabbit-hole hedge',
#  'moment go consider world she get',
#  'rabbit-hole go like tunnel way dip alice moment think stop herself she find herself',
#  'deep she fell she plenty time she go look her wonder go happen next',
#  'she try look make she come dark see anything she look fill cupboards book-shelves she saw map picture hang peg',
#  'she take jar shelve she pass label orange marmalade her great disappointment empty she drop jar fear kill somebody underneath manage put cupboards she fell',
#  '',
#  'think alice herself fall think nothing tumble stairs',
#  'brave think home',
#  'say anything fell top house',
#  'true',
#  '',
#  'fall come end',
#  'wonder many miles fall time',
#  'she say aloud.',
#  'get centre earth',
#  'let see thousand miles see several things sort her lessons schoolroom good opportunity show her knowledge listen her good practice say -yes right distance-but wonder latitude longitude get',
#  'alice idea latitude longitude think nice grand word say',
#  'she begin',
#  'wonder fall right earth',
#  'funny seem come people walk head downward',
#  'antipathies think- she glad listen time sound word -but ask name country know',
#  "please ma'am new zealand australia",
#  'she try curtsey she spoke-fancy curtsey fall air',
#  'think manage',
#  'ignorant little girl she think ask',
#  'ask see',
#  '',
#  'nothing begin talk',
#  'dinah miss much to-night think',
#  'dinah cat',
#  'hope remember her saucer milk tea-time',
#  'dinah dear',
#  'wish',
#  'air afraid catch bat mouse know',
#  'cat eat bat wonder',
#  'alice begin get sleepy go say herself dreamy sort way cat eat bat',
#  'cat eat bat',
#  'bat eat cat',
#  'see she answer question matter way she put',
#  'she felt she doze begin dream she walk hand hand dinah say her dinah tell truth eat bat',
#  'thump',
#  'thump',
#  'she come heap stick dry leave fall',
#  'bite hurt she jump her feet moment she look dark her long passage white rabbit sight hurry',
#  'moment lose go wind time hear say turn corner oh ears whisker late get',
#  'she she turn corner rabbit see she find herself low hall light row lamps roof',
#  'doors round hall lock alice way side try door she walk middle wonder she get',
#  'she come upon little three-legged table make solid glass nothing tiny golden key alice think belong doors hall alas',
#  'lock large key small rate open',
#  'second time round she come low curtain she notice little door fifteen inch high she try little golden key lock her great delight fit',
#  'open door find lead small passage much larger rat-hole she kneel look passage loveliest garden saw',
#  'she get dark hall wander bed bright flower cool fountains she get her head doorway head go think poor alice little use shoulder',
#  'wish shut telescope',
#  'think know begin',
#  'see many out-of-the-way things happen alice begin think things impossible',
#  'seem use wait little door she go table half hop she find key rate book rule people telescope time she find little bottle say alice round neck bottle paper label word drink print large letter',
#  'say drink wise little alice go hurry',
#  "look first she say see mark 'poison she read several nice little histories children get burn eat wild beasts unpleasant things remember simple rule friends teach red-hot poker burn hold long cut finger deeply knife bleed she forget much bottle mark poison certain disagree sooner",
#  'bottle mark poison alice venture taste find nice fact sort mix flavour cherry-tart custard pine-apple roast turkey toffee hot butter she finish',
#  'curious feel',
#  'say alice shut telescope',
#  'she ten inch her face brighten think she right size go little door garden',
#  'she wait minutes see she go shrink she felt little nervous end know say herself go candle',
#  'wonder',
#  'she try fancy flame candle candle blow she remember see thing',
#  'find nothing happen she decide go garden alas poor alice',
#  'she get door she find she forget little golden key she go table she find she reach she see glass she try her best climb legs table slippery she tire herself try poor little thing sit cry',
#  'come use cry',
#  'say alice herself leave minute',
#  'she give herself good advice she follow she scold herself bring her eye she remember try box her ears cheat herself game croquet she play herself curious child fond pretend people',
#  'use think poor alice pretend people',
#  'enough leave make respectable person',
#  'her eye fell little glass box lie table she open find small cake word eat mark currants',
#  'eat say alice make grow larger reach key make grow smaller creep door way get garden care happen',
#  'she eat little bite say herself way',
#  'way',
#  'hold her hand top her head feel way grow she surprise find she remain size sure happen eat cake alice get much way expect nothing out-of-the-way things happen seem dull stupid life go common way',
#  'she set work finish cake',
#  'pool curiouser curiouser',
#  'cry alice she much surprise moment she forget speak good english open largest telescope',
#  'good-bye feet',
#  'she look her feet seem sight get',
#  'oh poor little feet wonder put shoe stock dears',
#  'sure able',
#  'great deal trouble manage best way -but kind think walk way want go',
#  'let see give new pair boot christmas',
#  'she go plan herself she manage',
#  'go carrier she think funny seem send present feet',
#  'odd directions look',
#  'right foot esq. hearthrug fender alice love',
#  'dear nonsense talk',
#  'her head strike roof hall fact she feet high she take little golden key hurry garden door',
#  'poor alice',
#  'much she lie side look garden eye get hopeless she sit begin cry',
#  'ashamed say alice great girl she say go cry way',
#  'stop moment tell',
#  'she go shed gallons tear large pool round her inch reach half hall',
#  'time she hear little patter feet distance she dry her eye see come',
#  'white rabbit return dress pair white kid gloves hand large fan he come trot great hurry mutter himself he come oh',
#  'duchess duchess',
#  'oh',
#  'she savage keep her wait',
#  'alice felt desperate she ready ask help rabbit come her she begin low timid voice please sir- rabbit start drop white kid gloves fan skurried darkness he go',
#  'alice take fan gloves hall hot she keep fan herself time she go talk dear dear',
#  'queer everything to-day',
#  'yesterday things go usual',
#  'wonder change night',
#  'let think get morning',
#  'think remember feel little different',
#  'next question world',
#  'great puzzle',
#  'she begin think children she know age herself see she change',
#  'sure ada she say her hair go long ringlets mine go ringlets sure mabel know sort things she oh',
#  'she know little',
#  'she she and-oh dear puzzle',
#  'try know things use know',
#  'let see time twelve time thirteen time is-oh dear',
#  'get twenty rate',
#  'multiplication table signify let try geography',
#  'london capital paris paris capital rome rome-no wrong certain',
#  'change mabel',
#  'try say doth little- she cross her hand her lap she say lessons begin repeat her voice sound hoarse strange word come use little crocodile improve his shin tail pour water nile golden scale',
#  'he seem spread his claw welcome little fish smile jaw',
#  'sure right word say poor alice her eye fill tear she go mabel go live poky little house toy play oh',
#  'many lessons learn',
#  'make mind mabel stay',
#  "use put head say 'come dear",
#  "look say 'who",
#  "tell person come stay somebody else'-but oh dear",
#  'cry alice sudden burst wish put head',
#  'tire',
#  'she say she look her hand surprise see she put rabbit little white kid gloves she talk',
#  '',
#  'she thought.',
#  'grow small',
#  'she get go table measure herself find she guess she feet high go shrink she find cause fan she hold she drop time avoid shrink',
#  'narrow escape',
#  'say alice good deal frighten sudden change glad find herself existence garden',
#  'she run speed little door alas',
#  'little door shut little golden key lie glass table things worse think poor child small',
#  'declare bad',
#  'she say word her foot slip moment splash',
#  'she her chin salt water',
#  'her first idea she somehow fall sea case go railway she say herself',
#  'alice seaside her life come general conclusion go english coast find number bath machine sea children dig sand wooden spade row lodge house railway station',
#  'she make she pool she weep she feet high.',
#  'wish cry much',
#  'say alice she swim try find her way',
#  'punish suppose drown tear',
#  'queer thing sure',
#  'everything queer to-day',
#  'she hear something splash pool little way she swim nearer make first she think walrus hippopotamus she remember small she she make mouse slip herself',
#  'use think speak mouse',
#  'everything think likely talk rate harm try',
#  'she begin mouse know way pool',
#  'tire swim mouse',
#  'alice think right way speak mouse she thing she remember see her brother latin grammar mouse-of mouse-to mouse-a mouse-o mouse',
#  'mouse look her seem her wink little eye say nothing',
#  'understand english think daresay french mouse come william conqueror',
#  'her knowledge history alice clear notion anything happen',
#  'she begin ou est chatte',
#  'first sentence her french lesson-book',
#  'give sudden leap water seem',
#  'oh beg pardon',
#  'cry alice afraid she hurt poor animal feelings.',
#  'forget cat',
#  'cat',
#  'cry mouse shrill passionate voice',
#  'like cat',
#  'say alice soothe tone angry',
#  'wish show cat dinah think take fancy cat see her',
#  'she dear quiet thing alice go half herself she swim pool she sit purr fire lick her paw wash her face-and she nice soft thing nurse-and she capital catch mice-oh beg pardon',
#  'cry alice time mouse she felt certain offend',
#  'talk her',
#  '',
#  'cry mouse tremble end his tail',
#  'talk subject',
#  'family cat nasty low vulgar things',
#  'let hear name',
#  '',
#  'say alice great hurry change subject conversation',
#  'you-are fond-of-of dog',
#  'mouse answer alice go nice little dog house show',
#  'little bright-eyed terrier know brown hair',
#  'fetch things throw sit beg dinner sort things- remember half them-and belong farmer know he say useful worth pound',
#  'he say kill rat and-oh dear',
#  'cry alice sorrowful tone afraid offend',
#  'mouse swim her hard go make quite commotion pool go',
#  'she call mouse dear',
#  'come talk cat dog',
#  'mouse hear turn round swim her face pale passion alice think say low tremble voice let us get tell history understand hate cat dog',
#  'high time go pool get crowd bird animals fall duck dodo lory eaglet several curious creatures',
#  'lead way whole party swim shore',
#  'caucus-race long tale queer-looking party assemble bank-the bird draggle feather animals fur cling close drip wet cross uncomfortable',
#  'first question course get dry consultation minutes seem natural alice find herself talk she know her life',
#  'she argument lory last turn sulky say older know better alice allow know old lory refuse tell age say',
#  'last mouse seem person authority call sit listen',
#  'make dry',
#  'sit large ring mouse middle',
#  'keep her eye fix she felt sure she catch bad cold she get dry',
#  'ahem',
#  'say mouse important air ready',
#  'driest thing know',
#  'silence round please',
#  'conqueror cause favour pope submit english want leaders much accustom usurpation conquest',
#  'edwin morcar earls mercia northumbria-',
#  'say lory shiver.',
#  'beg pardon',
#  'say mouse frown speak',
#  '',
#  'say lory hastily.',
#  'think say mouse',
#  'proceed',
#  'morcar earls mercia northumbria declare him stigand patriotic archbishop canterbury find advisable- find',
#  'say duck',
#  'find mouse reply course know mean',
#  "know 'it mean find thing say duck frog worm",
#  'question archbishop find',
#  "mouse notice question go '-found advisable go edgar atheling meet william offer him crown",
#  'william conduct moderate',
#  'insolence his normans- get',
#  'continue turn alice speak',
#  'wet say alice melancholy tone seem dry',
#  'case say dodo rise feet move adjourn immediate adoption energetic remedies- speak english',
#  'say eaglet.',
#  'know mean half long word believe',
#  'eaglet bend head hide smile bird titter',
#  'go say say dodo offend tone best thing get us dry caucus-race',
#  'caucus-race',
#  'say alice she want much know dodo think somebody speak seem incline say anything',
#  'say dodo best way explain',
#  'like try thing winter day tell dodo manage',
#  'mark race-course sort circle exact shape matter say party place course',
#  'begin run leave easy know race',
#  'run hour dry dodo call race',
#  'crowd round pant win',
#  'question dodo answer great deal think sit long time finger press forehead position see shakespeare picture him rest wait silence',
#  'last dodo say everybody win prize',
#  'give prize',
#  'chorus voice ask',
#  'she course say dodo point alice finger whole party crowd round her call confuse way prize',
#  'prize',
#  'alice idea despair she put her hand her pocket pull box comfit salt water get hand round prize',
#  'a-piece round',
#  'she prize herself know say mouse',
#  'course dodo reply',
#  'get pocket',
#  'he go turn alice',
#  'thimble say alice',
#  'hand say dodo',
#  'crowd round her dodo present thimble say beg acceptance elegant thimble finish short speech cheer',
#  'think whole thing absurd look grave she dare she think anything say she bow take thimble look solemn she',
#  'next thing eat comfit cause noise confusion large bird complain taste small ones choke pat',
#  'last sit ring beg mouse tell something',
#  'promise tell history know say alice hate- she add whisper half afraid offend',
#  'mine long sad tale',
#  'say mouse turn alice sigh',
#  'long tail say alice look wonder mouse tail call sad',
#  'she keep puzzle mouse speak her idea tale something fury say he meet house us go law prosecute you.-come take denial trial morning nothing',
#  "say mouse cur 'such trial dear sir jury judge waste breath",
#  'judge jury say cunning old fury try whole cause condemn death',
#  'attend',
#  'say mouse alice',
#  'think',
#  'beg pardon say alice get fifth bend think',
#  '',
#  'cry mouse',
#  'knot',
#  'say alice ready make herself useful look her',
#  'oh let help undo',
#  'nothing sort say mouse get walk',
#  'insult talk nonsense',
#  'mean',
#  'plead poor alice',
#  'offend know',
#  'mouse growl reply',
#  'please come finish story',
#  'call others join chorus please',
#  'shake head walk little quicker',
#  'pity stay',
#  'sigh lory sight old crab take opportunity say her daughter ah dear',
#  'let lesson lose temper',
#  'hold tongue',
#  'say young crab little snappishly',
#  'enough try patience oyster',
#  'wish dinah know',
#  'say alice aloud address nobody particular',
#  'she fetch',
#  'dinah venture ask question',
#  'say lory',
#  'she ready talk her pet dinah cat',
#  'she capital catch mice think',
#  'wish see her bird',
#  'she eat little bird look',
#  'speech cause remarkable sensation party',
#  'bird hurry old magpie begin remark get home night-air suit throat',
#  'canary call tremble voice children come dears',
#  'high time bed',
#  'various pretexts move leave alone.',
#  'wish mention dinah',
#  'she say herself melancholy tone',
#  'nobody seem her sure she best cat world',
#  'dear dinah',
#  'wonder see',
#  'poor alice begin cry she felt low-spirited',
#  'little she hear little patter footsteps distance she look half hop mouse change his mind come finish his story',
#  'rabbit send little bill white rabbit trot look go lose something she hear mutter duchess',
#  'duchess',
#  'dear paw',
#  'fur whisker',
#  'she get execute sure ferret ferret',
#  'drop wonder',
#  'alice guess moment look fan pair white kid gloves she begin hunt seen-everything seem change her swim pool great hall glass table little door vanish',
#  'rabbit notice alice she go hunt call her angry tone mary ann',
#  'run home moment fetch pair gloves fan',
#  'quick',
#  'frighten she run direction point try explain mistake make',
#  'he take his housemaid she say herself she run',
#  'surprise he he find',
#  'take him his fan gloves-that find',
#  'she say she come neat little house door bright brass plate name w. rabbit engrave',
#  'she go knock hurry upstairs great fear lest she meet real mary ann turn house she find fan gloves',
#  'queer seem alice say herself go message rabbit',
#  'suppose dinah send message next',
#  'she begin fancy sort thing happen alice',
#  'come get ready walk',
#  "'coming minute nurse",
#  'get see get',
#  'think alice go let dinah stop house begin order people',
#  'time she find her way tidy little room table window she hop fan pair tiny white kid gloves she take fan pair gloves go leave room her eye fell little bottle stand looking-glass',
#  'label time word drink she uncork put her lips.',
#  'know something interest sure happen she say herself eat drink anything see bottle',
#  'hope make grow large quite tire tiny little thing',
#  'much sooner she expect she drink half bottle she find her head press ceiling stoop save her neck break',
#  'she put bottle say herself enough- hope grow more-as get door- wish drink much',
#  'alas',
#  'late wish',
#  'she go grow grow kneel floor minute room she try effect lie elbow door arm curl round her head',
#  'she go grow last resource she put arm window foot chimney say herself happen',
#  'become',
#  'little magic bottle full effect she grow larger uncomfortable seem sort chance her get room wonder she felt unhappy',
#  'much pleasanter home think poor alice grow larger smaller order mice rabbit',
#  'wish go rabbit-hole-and yet-and yet-it curious know sort life',
#  'wonder happen',
#  'use read fairy-tales fancy kind thing happen',
#  'book write',
#  'grow write one-but grow she add sorrowful tone least room grow',
#  'think get older',
#  'comfort way-never old woman-but then-always lessons learn',
#  'oh',
#  'oh foolish alice',
#  'she answer herself',
#  'learn lessons',
#  'room room lesson-books',
#  'she go take side make quite conversation minutes she hear voice stop listen',
#  'mary ann',
#  'mary ann',
#  'say voice',
#  'fetch gloves moment',
#  'come little patter feet stairs',
#  'alice know rabbit come look her she tremble till she shake house quite forget she thousand time large rabbit reason afraid',
#  'rabbit come door try open door open inwards press hard attempt prove failure',
#  'alice hear say go round get window',
#  '',
#  'think alice wait till she fancy she hear rabbit window she spread her hand make snatch air',
#  'she get hold anything she hear little shriek fall crash break glass she conclude possible fall cucumber-frame something sort',
#  "next come angry voice-the rabbit's- pat",
#  'pat',
#  '',
#  'voice she hear sure',
#  'dig apples honour',
#  'dig apples',
#  'say rabbit',
#  '',
#  'come help',
#  'sound break glass',
#  'tell pat window',
#  'sure arm yer honour',
#  'he pronounce arrum',
#  'arm goose',
#  'saw size',
#  'fill whole window',
#  'sure yer honour arm',
#  'get business rate go take',
#  'long silence alice hear sure yer honour',
#  'tell coward',
#  'last she spread her hand make snatch air',
#  'time little shriek sound break glass',
#  'number cucumber-frames',
#  'think',
#  'wonder',
#  "pull window wish '",
#  'sure want stay',
#  'she wait time hear anything last come rumble little cartwheel sound good many voice talk together she make word ladder -why bring bill get other-bill',
#  'fetch lad -here put corner-no tie first-they reach half high yet-oh',
#  'particular-here bill',
#  'catch hold rope-will roof bear loose slate-oh come',
#  'head',
#  'loud crash -it bill fancy-who go chimney -nay sha',
#  '-bill go down-here bill',
#  'master say go chimney',
#  'oh',
#  'bill get come chimney he',
#  'say alice herself',
#  'shy seem put everything upon bill',
#  'bill place good deal fireplace narrow sure think kick little',
#  'she draw her foot chimney she wait till she hear little animal she guess sort scratch scramble chimney close her say herself bill she give sharp kick wait see happen next',
#  'first thing she hear general chorus go bill',
#  'rabbit voice along- catch him hedge',
#  'silence confusion voices- hold his head-brandy now-do choke him-how old fellow',
#  'happen',
#  'tell us',
#  'last come little feeble squeak voice bill think know-no thank ye better now-but deal fluster tell know something come jack-in-the-box go sky-rocket',
#  'old fellow',
#  'say others',
#  'burn house',
#  'say rabbit voice alice call loud she set dinah',
#  'dead silence think herself wonder next',
#  'sense take roof',
#  'minute begin move alice hear rabbit say barrowful begin',
#  'barrowful',
#  'think she long doubt next moment shower little pebbles come rattle window hit her face',
#  'put stop she say herself better',
#  'produce dead silence',
#  'alice surprise pebbles turn little cake lay floor bright idea come her head',
#  'eat cake she think sure make change size make larger make smaller suppose',
#  'she swallow cake delight find she begin',
#  'she small get door she run house quite crowd little animals wait',
#  'poor little lizard bill middle hold guinea-pigs give something bottle',
#  'make rush alice moment she appear she run she find herself safe thick wood',
#  'first thing get say alice herself she wander wood grow right size second thing find way garden',
#  'think best plan',
#  'sound excellent plan doubt arrange difficulty she smallest idea set she peer tree little sharp bark her head make her look great hurry',
#  'enormous puppy look her large round eye stretch paw try touch her',
#  'poor little thing',
#  'say alice coax tone she try hard whistle she frighten time think hungry case eat her spite her coax',
#  'know she she pick little bite stick hold puppy whereupon puppy jump air feet yelp delight rush stick make believe worry alice dodge great thistle keep herself run moment she appear side puppy make rush stick tumble head heel hurry get hold alice think game play cart-horse expect moment trample feet run puppy begin series short charge stick run little way forward time long way bark last sit good way pant tongue hang mouth great eye half shut',
#  'seem good opportunity make her escape she set run till she tire breath till puppy bark sound faint distance',
#  'dear little puppy',
#  'say alice she lean buttercup rest herself fan herself leave teach much if-if right size',
#  'dear',
#  'forget get grow',
#  'let see-how manage',
#  'suppose eat drink something great question',
#  'great question',
#  'alice look her flower grass she see anything look right thing eat drink circumstances',
#  'large mushroom grow her height herself she look occur her she look see top',
#  'she stretch herself tiptoe peep edge mushroom her eye meet large blue caterpillar sit top arm fold smoke long hookah take smallest her anything',
#  'advice caterpillar caterpillar alice look time silence last caterpillar take hookah mouth her languid sleepy voice',
#  '',
#  'say caterpillar',
#  'encourage open conversation',
#  'shyly know sir present-at least know get morning think change several time',
#  'mean',
#  'say caterpillar',
#  'explain',
#  'explain afraid sir say see',
#  'see say caterpillar.',
#  'afraid put reply understand begin many different size day confuse',
#  'say caterpillar',
#  'find say alice turn chrysalis-you day butterfly think feel little queer',
#  'bite say caterpillar',
#  'feel different say alice know feel queer',
#  '',
#  'say caterpillar',
#  '',
#  'bring begin conversation',
#  'alice felt little irritate caterpillar make short remark she draw herself say think tell',
#  '',
#  'say caterpillar',
#  'puzzle question alice think good reason caterpillar seem unpleasant state she turn',
#  'come',
#  'caterpillar call her',
#  'something important say',
#  'sound promise alice turn come',
#  'keep say caterpillar',
#  '',
#  'say alice her anger well she',
#  'say caterpillar',
#  'alice think she wait she nothing tell her something worth hear',
#  'minutes puff speak last unfold arm take hookah mouth say think change',
#  'afraid sir say alice remember things used-and keep size ten minutes',
#  'remember things',
#  'say caterpillar',
#  'try say doth little busy bee come different',
#  'melancholy voice',
#  'repeat old father william say caterpillar',
#  'alice fold her hand begin old father william young man say hair become white stand head- think age right',
#  'youth father william reply his son fear injure brain sure none',
#  'old say youth mention grow fat turn back-somersault door- pray reason',
#  'youth say sage he shake his grey lock keep limbs supple use ointment-one shill box- allow sell couple',
#  'old say youth jaw weak anything tougher suet finish goose bone beak- pray manage',
#  'youth say his father take law argue case wife muscular strength give jaw last rest life',
#  'old say youth suppose eye steady balance eel end nose- make clever',
#  'answer question enough say his father give air',
#  'think listen day stuff',
#  'kick stairs',
#  'say right say caterpillar',
#  'right afraid say word get alter',
#  'wrong begin end say caterpillar silence minutes',
#  'caterpillar speak',
#  'size want',
#  'ask',
#  'oh particular size alice reply change know',
#  'know say caterpillar',
#  'alice say nothing she contradict her life she felt she lose her temper',
#  'content',
#  'say caterpillar',
#  'little larger sir mind say alice inch wretched height',
#  'good height',
#  'say caterpillar rear upright speak inch high',
#  'use',
#  'plead poor alice piteous tone',
#  'she think herself wish creatures offend',
#  'get use time say caterpillar put hookah mouth begin smoke',
#  'time alice wait choose speak',
#  'minute caterpillar take hookah mouth yawn shake',
#  'get mushroom crawl grass remark go side make grow taller side make grow shorter',
#  'side',
#  'side',
#  'think alice herself',
#  'mushroom say caterpillar she ask aloud moment sight',
#  'alice remain look mushroom minute try make side round she find difficult question',
#  'last she stretch her arm round go break bite edge hand',
#  '',
#  'she say herself nibble little right-hand bite try effect next moment she felt violent blow her chin strike her foot',
#  'she good deal frighten sudden change she felt time lose she shrink she set work eat bite',
#  'her chin press her foot room open her mouth she last manage swallow morsel lefthand bite',
#  'come head free last',
#  'say alice tone delight change alarm moment she find her shoulder nowhere find she see she look immense length neck seem rise stalk sea green leave lay her',
#  'green stuff',
#  'say alice',
#  'shoulder get',
#  'oh poor hand see',
#  'she move she speak result seem follow little shake distant green leave',
#  'seem chance get her hand her head she try get her head delight find her neck bend direction serpent',
#  'she succeed curve graceful zigzag go dive leave she find nothing top tree she wander sharp hiss make her draw hurry large pigeon fly her face beat her wing',
#  'serpent',
#  'scream pigeon.',
#  'serpent',
#  'say alice',
#  'let',
#  'serpent say',
#  'repeat pigeon subdue tone add kind sob try way nothing seem suit',
#  'least idea talk say alice',
#  'try root tree try bank try hedge pigeon go attend her serpents',
#  'please',
#  'alice puzzle she think use say anything till pigeon finish',
#  'trouble enough hatch egg say look-out serpents night day',
#  'wink sleep weeks',
#  'sorry annoy say alice begin see mean',
#  'take highest tree wood continue pigeon raise voice shriek think free last need come sky',
#  'ugh serpent',
#  'serpent tell',
#  'say',
#  'a- a-',
#  '',
#  'say pigeon.',
#  'see try invent something',
#  'little girl say alice she remember number change she go day',
#  'likely story',
#  'say pigeon tone deepest contempt',
#  'see good many little girls time neck',
#  '',
#  'serpent use deny',
#  'tell next taste egg',
#  'taste egg say truthful child little girls eat egg much serpents know',
#  'believe say kind serpent say',
#  'new idea alice she silent minute give pigeon opportunity add look egg know matter little girl serpent',
#  'matter good deal say alice look egg happen want raw',
#  '',
#  'say pigeon sulky tone settle nest',
#  'crouch tree well she her neck keep get entangle branch she stop untwist',
#  'she remember she hold piece mushroom her hand she set work nibble first grow taller shorter she succeed bring herself her usual height',
#  'she anything right size felt strange first she get use minutes begin talk herself usual',
#  'come half plan',
#  'puzzle change',
#  'sure go minute',
#  'get right size next thing get beautiful garden-how wonder',
#  'she say she come open place little house feet high',
#  'live think come size frighten wits',
#  'she begin nibble righthand bite venture go house till she bring herself inch high',
#  'pig minute she stand look house wonder footman livery come run wood- she consider him footman he livery judge his face she call him fish -and rap door his knuckle',
#  'open footman livery round face large eye frog footmen alice powder hair curl head',
#  'she felt curious know creep little way wood listen',
#  'fish-footman begin produce his arm great letter large himself he hand say solemn tone duchess',
#  'invitation queen play croquet',
#  'frog-footman repeat solemn tone change order word little queen',
#  'invitation duchess play croquet',
#  'low curl get',
#  'much she run wood fear her she next peep fish-footman go sit grind door star sky',
#  'alice go door knock',
#  'sort use knock say footman reason',
#  'side door make noise hear',
#  'extraordinary noise go within-a constant howl sneeze great crash dish kettle break piece',
#  'please say alice get',
#  'sense knock footman go her door us',
#  'instance knock let know',
#  'he look sky time he speak alice think uncivil',
#  'he help she say herself his eye top his head',
#  'rate he answer questions.-how get',
#  'she repeat aloud.',
#  'sit footman remark till tomorrow- moment door house open large plate come skim straight footman head graze his nose break piece tree him',
#  '-or next day footman continue tone nothing happen',
#  'get',
#  'ask alice louder tone',
#  'get',
#  'say footman',
#  'first question know',
#  'doubt alice tell',
#  'dreadful she mutter herself way creatures argue',
#  'drive crazy',
#  'footman seem think good opportunity repeat his remark variations.',
#  'sit he say days days',
#  '',
#  'say alice',
#  'anything say footman begin whistle',
#  'use talk him say he idiotic',
#  'she open door go',
#  'door lead large kitchen full smoke end duchess sit three-legged stool middle nurse baby cook lean fire stir large cauldron seem full soup',
#  'much soup',
#  'alice say herself she sneeze',
#  'air',
#  'duchess sneeze baby sneeze howl moment pause',
#  'things kitchen sneeze cook large cat sit hearth grin ear ear',
#  'please tell say alice she sure good manners her speak first cat grin',
#  'cheshire cat say duchess',
#  'pig',
#  'she say last word sudden violence alice jump she saw moment address her she take courage go know cheshire cat grin fact know cat grin',
#  "say duchess 'em",
#  'know alice say feel please get conversation',
#  'know say duchess fact',
#  'alice tone remark think introduce subject conversation',
#  'she try fix cook take cauldron soup fire set work throw everything her reach duchess baby-the fire-irons come follow shower saucepans plat dish',
#  'duchess take notice hit her baby howl much impossible say blow hurt',
#  'oh please mind',
#  'cry alice jump agony terror',
#  'go his precious nose',
#  'large saucepan fly carry',
#  'everybody mind business duchess say hoarse growl world go round deal',
#  'advantage say alice felt glad get opportunity show little her knowledge',
#  'think work make day night',
#  'see earth take twenty-four hours turn round axis- talk ax say duchess chop her head',
#  'alice glance cook see she mean take hint cook stir soup seem listen she go twenty-four hours think twelve',
#  'say duchess abide figure',
#  'she begin her child sing sort lullaby she give violent shake end line speak little boy beat him he sneeze he annoy he know tease',
#  'chorus',
#  'cook baby join wow',
#  'wow',
#  'wow',
#  'duchess sing second verse song she keep toss baby poor little thing howl alice hear word speak boy beat him he sneeze he enjoy he please',
#  'chorus',
#  'wow',
#  'wow',
#  'wow',
#  '',
#  'nurse bite',
#  'duchess say alice fling baby her she spoke.',
#  'go get ready play croquet she hurry room',
#  'cook throw frying-pan her she go her',
#  'catch baby difficulty queer-shaped little creature hold arm legs directions star-fish think alice',
#  'poor little thing snort steam-engine she catch keep double straighten first minute much she hold',
#  'she make proper way nurse twist sort knot keep tight hold right ear leave foot prevent undo she carry open air',
#  'take child think sure kill day murder leave',
#  'she say last word loud little thing grunt reply leave sneeze time',
#  'grunt say alice proper way express',
#  'baby grunt alice look face see matter',
#  'doubt turn-up much snout real nose eye get small baby alice look thing',
#  'sob she think look eye see tear',
#  'tear',
#  'go turn pig dear say nothing',
#  'mind',
#  'poor little thing sob grunt impossible say go silence',
#  'think herself creature get home',
#  'grunt she look face alarm',
#  'time mistake less pig she felt absurd her carry',
#  'she set little creature felt relieve see trot wood',
#  'grow she say herself make child make handsome pig think',
#  'she begin think children she know pig say herself know right way change them- she little startle see cheshire cat sit tree yards',
#  'cat grin saw alice',
#  'look good-natured she think claw great many teeth she felt treat respect',
#  'cheshire puss she begin timidly she know like name grin little wider',
#  'come please think alice she go',
#  'tell please way go',
#  'depend good deal want get say cat.',
#  'much care where- say alice',
#  'matter way go say cat',
#  '-so long get add explanation',
#  'oh sure say cat walk',
#  'alice felt deny she try question',
#  'sort people live',
#  'direction cat say wave right paw round live hatter direction wave paw live march hare',
#  'visit mad',
#  'want go mad people alice remark',
#  'oh help say cat mad',
#  'mad',
#  'mad',
#  'know mad',
#  'say alice',
#  'say cat come',
#  'alice think she go know mad',
#  'begin say cat dog mad',
#  'grant',
#  'suppose say alice',
#  'cat go see dog growl angry wag tail please',
#  'growl please wag tail angry',
#  'mad',
#  'call purr growl say alice',
#  'call say cat',
#  'play croquet queen to-day',
#  'much say alice invite',
#  'see say cat vanish',
#  'much surprise she get use queer things happen',
#  'she look place appear',
#  'by-the-bye become baby',
#  'say cat.',
#  'forget ask',
#  'turn pig alice say come natural way.',
#  'think say cat vanish',
#  'little half expect see appear minute she walk direction march hare say live',
#  'see hatters she say herself march hare much interest rave mad-at least mad march',
#  'she say she look cat sit branch tree',
#  'say pig fig',
#  'say cat.',
#  'say pig reply alice wish keep appear vanish make quite giddy',
#  'right say cat time vanish begin end tail end grin remain time rest go',
#  '',
#  'see cat grin think grin cat',
#  'curious thing saw life',
#  'she go she come sight house march hare she think house chimneys shape ears roof thatch fur',
#  'large house she go nearer till she nibble lefthand bite mushroom raise herself feet high she walk say herself suppose rave mad',
#  'wish go see',
#  'mad tea-party table set tree front house march hare hatter tea dormouse sit use cushion rest elbow talk head',
#  'uncomfortable dormouse think asleep suppose mind',
#  'table large crowd corner room',
#  'room',
#  'cry saw come',
#  'plenty room',
#  'say alice she sit large arm-chair end table',
#  'wine march hare say encourage tone',
#  'alice look round table nothing tea.',
#  'see wine she remark',
#  'say march hare',
#  'civil offer say alice',
#  'civil sit invite say march hare.',
#  'know table say alice lay great many',
#  'hair want cut say hatter',
#  'he look alice time great curiosity his first speech',
#  'learn make personal remark alice say severity rude',
#  'hatter open his eye wide hear he say raven writing-desk',
#  'come fun',
#  'think',
#  'glad begin ask riddles.- believe guess she add aloud',
#  'mean think find answer',
#  'say march hare',
#  'say alice',
#  'say mean march hare go',
#  'reply least-at least mean say-that thing know',
#  'thing bite',
#  'say hatter',
#  'say see eat thing eat see',
#  'say march hare get thing get',
#  'say add seem talk his sleep breathe sleep thing sleep breathe',
#  'thing say hatter conversation drop party sit silent minute alice think she remember raven writing-desks much',
#  'hatter break silence',
#  'day month',
#  'he say turn alice he take his watch his pocket look shake hold his ear',
#  'alice consider little say fourth',
#  'days wrong',
#  'sigh hatter.',
#  'tell butter suit work',
#  'he add look march hare',
#  'best butter march hare reply',
#  'crumb get grumble put bread-knife',
#  'march hare take watch look he dip his cup tea look he think nothing say his first remark best butter know',
#  'alice look his shoulder curiosity',
#  'funny watch',
#  'she remark',
#  "day month tell o'clock",
#  '',
#  'mutter hatter',
#  'watch tell year',
#  'course alice reply stay year time',
#  'case mine say hatter',
#  'alice felt puzzle',
#  'hatter remark seem sort mean english.',
#  'understand she say she',
#  'dormouse asleep say hatter he pour little hot tea nose',
#  'dormouse shake head say open eye course course go remark',
#  'guess riddle',
#  'hatter say turn alice',
#  'give alice reply answer',
#  'slightest idea say hatter',
#  'say march hare',
#  'sigh wearily.',
#  'think something better time she say waste ask riddle answer',
#  'know time say hatter talk waste',
#  'him',
#  'know mean say alice',
#  'course',
#  'hatter say his head contemptuously.',
#  'dare say speak time',
#  'reply know beat time learn music',
#  'ah',
#  'account say hatter',
#  'he stand beat',
#  'keep good term him he anything clock',
#  'instance suppose morning time begin lessons whisper hint time round go clock twinkle',
#  'half-past time dinner',
#  'wish march hare say whisper',
#  'grand say alice then- hungry know',
#  'first say hatter keep half-past long',
#  'way manage',
#  'alice ask',
#  'hatter shake his head',
#  '',
#  'he reply',
#  'quarrel last march-just he go mad know- point his tea spoon march hare -it great concert give queen hearts sing twinkle little bat',
#  'wonder',
#  'know song',
#  'hear something say alice',
#  'go know hatter continue way world fly tea-tray sky',
#  'twinkle twinkle- dormouse shake begin sing sleep twinkle twinkle twinkle twinkle- go long pinch make stop',
#  'finish first verse say hatter queen jump bawl murder time',
#  'his head',
#  'savage',
#  'exclaim alice',
#  'hatter go mournful tone he thing ask',
#  "o'clock",
#  'bright idea come alice head',
#  'reason many tea-things put',
#  'she ask',
#  'yes say hatter sigh tea-time time wash things whiles',
#  'keep move round suppose',
#  'say alice',
#  'say hatter things get use',
#  'happen come begin',
#  'alice venture ask',
#  'suppose change subject march hare interrupt yawning.',
#  'get tire',
#  'vote young lady tell us story',
#  'afraid know say alice alarm proposal',
#  'dormouse',
#  'cry',
#  'wake dormouse',
#  'pinch side',
#  'dormouse open his eyes.',
#  'asleep he say hoarse feeble voice hear word fellows say',
#  'tell us story',
#  'say march hare',
#  'please',
#  'plead alice',
#  'quick add hatter asleep',
#  'time little sisters dormouse begin great hurry name elsie lacie tillie live bottom well- live',
#  'say alice take great interest question eat drink',
#  'live treacle say dormouse think',
#  'know remark ill. say ill. alice try fancy herself extraordinary ways live like puzzle her much she go live bottom',
#  'take tea march hare say alice',
#  'nothing reply offend tone take',
#  'mean take less say hatter easy take nothing',
#  'nobody ask opinion say alice',
#  'make personal remark',
#  'hatter ask',
#  'know say she help herself tea bread-and-butter turn dormouse repeat her question',
#  'live bottom',
#  'dormouse take minute think say treacle-well',
#  'thing',
#  'begin hatter march hare go sh',
#  'sh',
#  'dormouse remark civil finish story',
#  'please go',
#  'alice say interrupt',
#  'dare say',
#  '',
#  'say dormouse',
#  'he consent go',
#  'little sisters-they learn draw know- draw',
#  'say alice forget her promise',
#  'treacle say dormouse consider time.',
#  'want clean cup interrupt hatter let move place',
#  'he he speak follow him march hare move dormouse place alice take place march hare',
#  'hatter get advantage change alice good deal worse march hare upset milk-jug his plate',
#  'wish offend dormouse she begin understand',
#  'draw treacle',
#  'draw water water-well say think draw treacle treacle-well-eh stupid',
#  'say dormouse choose notice last remark',
#  'course say -well',
#  'answer confuse poor alice she let dormouse go time interrupt',
#  'learn draw dormouse go yawn rub eye get sleepy draw manner things-everything begin',
#  'say alice',
#  '',
#  'say march hare',
#  'alice silent',
#  'dormouse close eye time go doze pinch hatter wake little shriek go begin mouse-traps moon memory muchness-you know say things much muchness -did see thing draw muchness',
#  'ask say confuse think- talk say hatter',
#  'piece rudeness alice bear she get great disgust walk dormouse fell others take least her go she look half hop call her last time she saw try put dormouse teapot',
#  'rate go',
#  'say alice she pick her way wood',
#  'stupidest tea-party life',
#  'she say she notice tree door lead right',
#  'curious',
#  'she think',
#  'everything curious today',
#  'think go',
#  'she go',
#  'she find herself little glass table',
#  'manage better time she say herself begin take little golden key unlock door lead garden',
#  'she go work nibble mushroom she keep piece her pocket till she foot high she walk little passage then-she find herself last beautiful garden bright flower-beds cool fountains',
#  'queen croquet-ground large rose-tree stand entrance garden roses grow white gardeners paint red',
#  'alice think curious thing she go nearer watch she come she hear say look',
#  'go splash paint',
#  'help say sulky tone jog elbow',
#  'look say right',
#  'lay blame others',
#  'better talk',
#  'say five.',
#  'hear queen say yesterday deserve behead',
#  '',
#  'say speak',
#  'none business',
#  'say',
#  'his business',
#  'say tell him-it bring cook tulip-roots onions',
#  'fling his brush begin unjust things- his eye chance fall alice she stand watch he check himself others look round bow low',
#  'tell say alice paint roses',
#  'say nothing look',
#  'begin low voice fact see miss red rose-tree put white mistake queen find head cut know',
#  'see miss best she come to- moment look garden call queen',
#  'queen',
#  'gardeners throw flat face',
#  'many footsteps alice look round eager see queen',
#  'come soldier carry club shape gardeners flat hand feet corner next ten courtiers ornament diamonds walk soldier',
#  'come royal children little dears come jump hand hand couple ornament hearts',
#  'next come guests kings queen alice recognise white rabbit talk hurry nervous manner smile everything say go her',
#  'follow knave hearts carry king crown crimson velvet cushion last grand procession come king queen hearts',
#  'alice doubtful she lie her face gardeners she remember hear rule processions besides use procession think she people lie upon face see',
#  'she stand she wait',
#  'procession come opposite alice stop look her queen say',
#  'she say knave hearts bow smile reply',
#  'idiot',
#  'say queen her head turn alice she go name child',
#  'name alice please majesty say alice she add herself pack card',
#  'afraid',
#  '',
#  'say queen point gardeners lie round rose-tree see lie face pattern rest pack she tell gardeners soldier courtiers her children',
#  'know',
#  'say alice surprise her courage',
#  'business mine',
#  'queen turn crimson fury glare her moment wild beast scream her head',
#  'off- nonsense',
#  'say alice queen silent',
#  'king lay his hand her arm say consider dear she child',
#  'queen turn him say knave turn',
#  'knave foot',
#  'get',
#  'say queen shrill loud voice gardeners jump begin bow king queen royal children everybody',
#  'leave',
#  'scream queen',
#  'make giddy',
#  'turn rose-tree she go',
#  'please majesty say humble tone go knee he speak trying- see',
#  'say queen examine roses',
#  'head',
#  'procession move soldier remain execute unfortunate gardeners run alice protection',
#  'behead',
#  'say alice she put large flower-pot stand',
#  'soldier wander minute look march others',
#  'head',
#  'shout queen',
#  'head go please majesty',
#  'soldier shout reply',
#  'right',
#  'shout queen',
#  'play croquet',
#  'silent look alice question mean her',
#  '',
#  'shout alice',
#  'come',
#  'roar queen alice join procession wonder happen next',
#  "it's-it fine day",
#  'say timid voice her side',
#  'she walk white rabbit peep her face',
#  'say alice duchess',
#  'hush',
#  'hush',
#  'say rabbit low hurry tone',
#  'he look his shoulder he speak raise himself tiptoe put his mouth her ear whisper she sentence execution',
#  '',
#  'say alice',
#  'say pity',
#  'rabbit ask',
#  'say alice think pity',
#  ...]

# %%
with open('clean_sentences_all.txt', 'w') as f:
    for item in clean_sentences_all:
        f.write("%s\n" % item)

# %% [markdown]
# ### Female characters

# %% [markdown]
# We basically need to obtain the sentences that contain the female characters' names + pronouns and then do a frequency count of those words or if we are working with domain list (which we will do) then after calculating the frequenc of each word we can filter the words based on the domain lists and aggregate frequencies by groups.

# %%
female_characters[:10]
# Out:
# ['fulvia',
#  'gwen',
#  'marjie',
#  'robby',
#  'jessica',
#  'gwendolin',
#  'bernardina',
#  'caron',
#  'pierette',
#  'fleur']

# %%
# replace female character names with she
female_sentences_replaced=[]
female_set = set(female_characters)
for i in range(len(clean_sentences_all)):
    sent_temp=[]
    for j in range(len(clean_sentences_all[i])):
        final_string = ' '.join("she" if i in female_set else i for i in clean_sentences_all[i][j].split())
        sent_temp.append(final_string)
    female_sentences_replaced.append(sent_temp)

# %%
female_sentences_replaced[:10]
# Out:
# [['illustration she adventure wonderland lewis carroll millennium fulcrum edition content rabbit-hole pool caucus-race long tale rabbit send little bill advice caterpillar pig pepper mad tea-party she croquet-ground',
#   'mock turtle story lobster quadrille steal tarts',
#   'she evidence rabbit-hole she begin get tire sit her sister bank nothing she peep book her sister read picture conversations use book think picture conversations',
#   'she consider her mind well she hot day make her feel sleepy stupid pleasure make daisy-chain worth trouble get pick daisies white rabbit pink eye run her',
#   'nothing remarkable she think much way hear rabbit say oh dear',
#   'dear',
#   'late',
#   'she think afterwards occur her she wonder time seem natural rabbit take watch waistcoat-pocket look hurry start her feet flash her mind she see rabbit waistcoat-pocket watch take burn curiosity she run field time see pop large rabbit-hole hedge',
#   'moment go consider world she get',
#   'rabbit-hole go like tunnel way dip she moment think stop herself she find herself',
#   'deep she fell she plenty time she go look her wonder go happen next',
#   'she try look make she come dark see anything she look fill cupboards book-shelves she saw map picture hang she',
#   'she take jar shelve she pass label orange marmalade her great disappointment empty she drop jar fear kill somebody underneath manage put cupboards she fell',
#   '',
#   'think she herself fall think nothing tumble stairs',
#   'brave think home',
#   'say anything fell top house',
#   'true',
#   '',
#   'fall come end',
#   'wonder many miles fall time',
#   'she say aloud.',
#   'get centre earth',
#   'let see thousand miles see several things sort her lessons schoolroom good opportunity show her knowledge listen her good practice say -yes right distance-but wonder latitude longitude get',
#   'she idea latitude longitude think nice grand word say',
#   'she begin',
#   'wonder fall right earth',
#   'funny seem come people walk head downward',
#   'antipathies think- she she listen time sound word -but ask name country know',
#   "please ma'am new zealand australia",
#   'she try curtsey she spoke-fancy curtsey fall air',
#   'think manage',
#   'ignorant little girl she think ask',
#   'ask see',
#   '',
#   'nothing begin talk',
#   'she miss much to-night think',
#   'she cat',
#   'she remember her saucer milk tea-time',
#   'she dear',
#   'wish',
#   'air afraid catch bat mouse know',
#   'cat eat bat wonder',
#   'she begin get sleepy go say herself dreamy sort way cat eat bat',
#   'cat eat bat',
#   'bat eat cat',
#   'see she answer question matter way she put',
#   'she felt she doze begin dream she walk hand hand she say her she tell truth eat bat',
#   'thump',
#   'thump',
#   'she come heap stick dry leave fall',
#   'bite hurt she jump her feet moment she look dark her long passage white rabbit sight hurry',
#   'moment lose go wind time hear say turn corner oh ears whisker late get',
#   'she she turn corner rabbit see she find herself low hall light she lamps roof',
#   'doors round hall lock she way side try door she walk middle wonder she get',
#   'she come upon little three-legged table make solid glass nothing tiny golden key she think belong doors hall alas',
#   'lock large key small rate open',
#   'second time round she come low curtain she notice little door fifteen inch high she try little golden key lock her great delight fit',
#   'open door find lead small passage much larger rat-hole she kneel look passage loveliest garden saw',
#   'she get dark hall wander bed bright she cool fountains she get her head doorway head go think poor she little use shoulder',
#   'wish shut telescope',
#   'think know begin',
#   'see many out-of-the-way things happen she begin think things impossible',
#   'seem use wait little door she go table half hop she find key rate book rule people telescope time she find little bottle say she round neck bottle paper label word drink print large letter',
#   'say drink wise little she go hurry',
#   "look first she say see mark 'poison she read several nice little histories children get burn eat wild beasts unpleasant things remember simple rule friends teach red-hot poker burn hold long cut finger deeply knife bleed she forget much bottle mark poison certain disagree sooner",
#   'bottle mark poison she venture taste find nice fact sort mix flavour cherry-tart custard pine-apple roast turkey toffee hot butter she finish',
#   'curious feel',
#   'say she shut telescope',
#   'she ten inch her face brighten think she right size go little door garden',
#   'she wait minutes see she go shrink she felt little nervous end know say herself go candle',
#   'wonder',
#   'she try she flame candle candle blow she remember see thing',
#   'find nothing happen she decide go garden alas poor she',
#   'she get door she find she forget little golden key she go table she find she reach she see glass she try her best climb legs table slippery she tire herself try poor little thing sit cry',
#   'come use cry',
#   'say she herself leave minute',
#   'she give herself good advice she follow she scold herself bring her eye she remember try box her ears cheat herself game croquet she play herself curious child fond pretend people',
#   'use think poor she pretend people',
#   'enough leave make respectable person',
#   'her eye fell little glass box lie table she open find small cake word eat mark currants',
#   'eat say she make grow larger reach key make grow smaller creep door way get garden care happen',
#   'she eat little bite say herself way',
#   'way',
#   'hold her hand top her head feel way grow she surprise find she remain size sure happen eat cake she get much way expect nothing out-of-the-way things happen seem dull stupid life go common way',
#   'she set work finish cake',
#   'pool curiouser curiouser',
#   'cry she she much surprise moment she forget speak good english open largest telescope',
#   'good-bye feet',
#   'she look her feet seem sight get',
#   'oh poor little feet wonder put shoe stock dears',
#   'sure able',
#   'great deal trouble manage best way -but kind think walk way want go',
#   'let see give new pair boot christmas',
#   'she go plan herself she manage',
#   'go carrier she think funny seem send present feet',
#   'odd directions look',
#   'right foot esq. hearthrug fender she she',
#   'dear nonsense talk',
#   'her head strike roof hall fact she feet high she take little golden key hurry garden door',
#   'poor she',
#   'much she lie side look garden eye get hopeless she sit begin cry',
#   'ashamed say she great girl she say go cry way',
#   'stop moment tell',
#   'she go shed gallons tear large pool round her inch reach half hall',
#   'time she hear little patter feet distance she dry her eye see come',
#   'white rabbit return dress pair white kid gloves hand large she he come trot great hurry mutter himself he come oh',
#   'duchess duchess',
#   'oh',
#   'she savage keep her wait',
#   'she felt desperate she ready ask help rabbit come her she begin low timid voice please sir- rabbit start drop white kid gloves she skurried darkness he go',
#   'she take she gloves hall hot she keep she herself time she go talk dear dear',
#   'queer everything to-day',
#   'yesterday things go usual',
#   'wonder change night',
#   'let think get morning',
#   'think remember feel little different',
#   'next question world',
#   'great puzzle',
#   'she begin think children she know age herself see she change',
#   'sure she she say her hair go long ringlets mine go ringlets sure she know sort things she oh',
#   'she know little',
#   'she she and-oh dear puzzle',
#   'try know things use know',
#   'let see time twelve time thirteen time is-oh dear',
#   'get twenty rate',
#   'multiplication table signify let try geography',
#   'london capital paris paris capital rome rome-no wrong certain',
#   'change she',
#   'try say doth little- she cross her hand her lap she say lessons begin repeat her voice sound hoarse strange word come use little crocodile improve his shin tail pour water nile golden scale',
#   'he seem spread his claw welcome little fish smile jaw',
#   'sure right word say poor she her eye fill tear she go she go live poky little house toy play oh',
#   'many lessons learn',
#   'make mind she stay',
#   "use put head say 'come dear",
#   "look say 'who",
#   "tell person come stay somebody else'-but oh dear",
#   'cry she sudden burst wish put head',
#   'tire',
#   'she say she look her hand surprise see she put rabbit little white kid gloves she talk',
#   '',
#   'she thought.',
#   'grow small',
#   'she get go table measure herself find she guess she feet high go shrink she find cause she she hold she drop time avoid shrink',
#   'narrow escape',
#   'say she good deal frighten sudden change she find herself existence garden',
#   'she run speed little door alas',
#   'little door shut little golden key lie glass table things worse think poor child small',
#   'declare bad',
#   'she say word her foot slip moment splash',
#   'she her chin salt water',
#   'her first idea she somehow fall sea case go railway she say herself',
#   'she seaside her life come general conclusion go english coast find number bath machine sea children dig sand wooden spade she lodge house railway station',
#   'she make she pool she weep she feet high.',
#   'wish cry much',
#   'say she she swim try find her way',
#   'punish suppose drown tear',
#   'queer thing sure',
#   'everything queer to-day',
#   'she hear something splash pool little way she swim nearer make first she think walrus hippopotamus she remember small she she make mouse slip herself',
#   'use think speak mouse',
#   'everything think likely talk rate harm try',
#   'she begin mouse know way pool',
#   'tire swim mouse',
#   'she think right way speak mouse she thing she remember see her brother latin grammar mouse-of mouse-to mouse-a mouse-o mouse',
#   'mouse look her seem her wink little eye say nothing',
#   'understand english think daresay french mouse come william conqueror',
#   'her knowledge history she clear notion anything happen',
#   'she begin ou est chatte',
#   'first sentence her french lesson-book',
#   'give sudden leap water seem',
#   'oh beg pardon',
#   'cry she afraid she hurt poor animal feelings.',
#   'forget cat',
#   'cat',
#   'cry mouse shrill passionate voice',
#   'like cat',
#   'say she soothe tone angry',
#   'wish show cat she think take she cat see her',
#   'she dear quiet thing she go half herself she swim pool she sit purr fire lick her paw wash her face-and she nice soft thing nurse-and she capital catch mice-oh beg pardon',
#   'cry she time mouse she felt certain offend',
#   'talk her',
#   '',
#   'cry mouse tremble end his tail',
#   'talk subject',
#   'family cat nasty low vulgar things',
#   'let hear name',
#   '',
#   'say she great hurry change subject conversation',
#   'you-are fond-of-of dog',
#   'mouse answer she go nice little dog house show',
#   'little bright-eyed terrier know brown hair',
#   'fetch things throw sit beg dinner sort things- remember half them-and belong farmer know he say useful worth pound',
#   'he say kill rat and-oh dear',
#   'cry she sorrowful tone afraid offend',
#   'mouse swim her hard go make quite commotion pool go',
#   'she call mouse dear',
#   'come talk cat dog',
#   'mouse hear turn round swim her face pale passion she think say low tremble voice let us get tell history understand hate cat dog',
#   'high time go pool get crowd she animals fall duck dodo she eaglet several curious creatures',
#   'lead way whole party swim shore',
#   'caucus-race long tale queer-looking party assemble bank-the she draggle feather animals fur cling close drip wet cross uncomfortable',
#   'first question course get dry consultation minutes seem natural she find herself talk she know her life',
#   'she argument she last turn sulky say older know better she allow know old she refuse tell age say',
#   'last mouse seem person authority call sit listen',
#   'make dry',
#   'sit large ring mouse middle',
#   'keep her eye fix she felt sure she catch bad cold she get dry',
#   'ahem',
#   'say mouse important air ready',
#   'driest thing know',
#   'silence round please',
#   'conqueror cause favour pope submit english want leaders much accustom usurpation conquest',
#   'edwin morcar earls mercia northumbria-',
#   'say she shiver.',
#   'beg pardon',
#   'say mouse frown speak',
#   '',
#   'say she hastily.',
#   'think say mouse',
#   'proceed',
#   'morcar earls mercia northumbria declare him stigand patriotic archbishop canterbury find advisable- find',
#   'say duck',
#   'find mouse reply course know mean',
#   "know 'it mean find thing say duck frog worm",
#   'question archbishop find',
#   "mouse notice question go '-found advisable go edgar atheling meet william offer him crown",
#   'william conduct moderate',
#   'insolence his normans- get',
#   'continue turn she speak',
#   'wet say she melancholy tone seem dry',
#   'case say dodo rise feet move adjourn immediate adoption energetic remedies- speak english',
#   'say eaglet.',
#   'know mean half long word believe',
#   'eaglet bend head hide smile she titter',
#   'go say say dodo offend tone best thing get us dry caucus-race',
#   'caucus-race',
#   'say she she want much know dodo think somebody speak seem incline say anything',
#   'say dodo best way explain',
#   'like try thing winter day tell dodo manage',
#   'mark race-course sort circle exact shape matter say party place course',
#   'begin run leave easy know race',
#   'run hour dry dodo call race',
#   'crowd round pant win',
#   'question dodo answer great deal think sit long time finger press forehead position see shakespeare picture him rest wait silence',
#   'last dodo say everybody win prize',
#   'give prize',
#   'chorus voice ask',
#   'she course say dodo point she finger whole party crowd round her call confuse way prize',
#   'prize',
#   'she idea despair she put her hand her pocket pull box comfit salt water get hand round prize',
#   'a-piece round',
#   'she prize herself know say mouse',
#   'course dodo reply',
#   'get pocket',
#   'he go turn she',
#   'thimble say she',
#   'hand say dodo',
#   'crowd round her dodo present thimble say beg acceptance elegant thimble finish short speech cheer',
#   'think whole thing absurd look grave she dare she think anything say she bow take thimble look solemn she',
#   'next thing eat comfit cause noise confusion large she complain taste small ones choke pat',
#   'last sit ring beg mouse tell something',
#   'promise tell history know say she hate- she add whisper half afraid offend',
#   'mine long sad tale',
#   'say mouse turn she sigh',
#   'long tail say she look wonder mouse tail call sad',
#   'she keep puzzle mouse speak her idea tale something fury say he meet house us go law prosecute you.-come take denial trial morning nothing',
#   "say mouse cur 'such trial dear sir jury judge waste breath",
#   'judge jury say cunning old fury try whole cause condemn death',
#   'attend',
#   'say mouse she',
#   'think',
#   'beg pardon say she get fifth bend think',
#   '',
#   'cry mouse',
#   'knot',
#   'say she ready make herself useful look her',
#   'oh let help undo',
#   'nothing sort say mouse get walk',
#   'insult talk nonsense',
#   'mean',
#   'plead poor she',
#   'offend know',
#   'mouse growl reply',
#   'please come finish story',
#   'call others join chorus please',
#   'shake head walk little quicker',
#   'pity stay',
#   'sigh she sight old crab take opportunity say her she ah dear',
#   'let lesson lose temper',
#   'hold tongue',
#   'say young crab little snappishly',
#   'enough try she oyster',
#   'wish she know',
#   'say she aloud address nobody particular',
#   'she fetch',
#   'she venture ask question',
#   'say she',
#   'she ready talk her she she cat',
#   'she capital catch mice think',
#   'wish see her she',
#   'she eat little she look',
#   'speech cause remarkable sensation party',
#   'she hurry old magpie begin remark get home night-air suit throat',
#   'canary call tremble voice children come dears',
#   'high time bed',
#   'various pretexts move leave alone.',
#   'wish mention she',
#   'she say herself melancholy tone',
#   'nobody seem her sure she best cat world',
#   'dear she',
#   'wonder see',
#   'poor she begin cry she felt low-spirited',
#   'little she hear little patter footsteps distance she look half hop mouse change his mind come finish his story',
#   'rabbit send little bill white rabbit trot look go lose something she hear mutter duchess',
#   'duchess',
#   'dear paw',
#   'fur whisker',
#   'she get execute sure ferret ferret',
#   'drop wonder',
#   'she guess moment look she pair white kid gloves she begin hunt seen-everything seem change her swim pool great hall glass table little door vanish',
#   'rabbit notice she she go hunt call her angry tone she she',
#   'run home moment fetch pair gloves she',
#   'quick',
#   'frighten she run direction point try explain mistake make',
#   'he take his housemaid she say herself she run',
#   'surprise he he find',
#   'take him his she gloves-that find',
#   'she say she come neat little house door bright brass plate name w. rabbit engrave',
#   'she go knock hurry upstairs great fear lest she meet real she she turn house she find she gloves',
#   'queer seem she say herself go message rabbit',
#   'suppose she send message next',
#   'she begin she sort thing happen she',
#   'come get ready walk',
#   "'coming minute nurse",
#   'get see get',
#   'think she go let she stop house begin order people',
#   'time she find her way tidy little room table window she hop she pair tiny white kid gloves she take she pair gloves go leave room her eye fell little bottle stand looking-glass',
#   'label time word drink she uncork put her lips.',
#   'know something interest sure happen she say herself eat drink anything see bottle',
#   'she make grow large quite tire tiny little thing',
#   'much sooner she expect she drink half bottle she find her head press ceiling stoop save her neck break',
#   'she put bottle say herself enough- she grow more-as get door- wish drink much',
#   'alas',
#   'late wish',
#   'she go grow grow kneel floor minute room she try effect lie elbow door arm curl round her head',
#   'she go grow last resource she put arm window foot chimney say herself happen',
#   'become',
#   'little magic bottle full effect she grow larger uncomfortable seem sort chance her get room wonder she felt unhappy',
#   'much pleasanter home think poor she grow larger smaller order mice rabbit',
#   'wish go rabbit-hole-and yet-and yet-it curious know sort life',
#   'wonder happen',
#   'use read fairy-tales she kind thing happen',
#   'book write',
#   'grow write one-but grow she add sorrowful tone least room grow',
#   'think get older',
#   'comfort way-never old woman-but then-always lessons learn',
#   'oh',
#   'oh foolish she',
#   'she answer herself',
#   'learn lessons',
#   'room room lesson-books',
#   'she go take side make quite conversation minutes she hear voice stop listen',
#   'she she',
#   'she she',
#   'say voice',
#   'fetch gloves moment',
#   'come little patter feet stairs',
#   'she know rabbit come look her she tremble till she shake house quite forget she thousand time large rabbit reason afraid',
#   'rabbit come door try open door open inwards press hard attempt prove failure',
#   'she hear say go round get window',
#   '',
#   'think she wait till she she she hear rabbit window she spread her hand make snatch air',
#   'she get hold anything she hear little shriek fall crash break glass she conclude possible fall cucumber-frame something sort',
#   "next come angry voice-the rabbit's- pat",
#   'pat',
#   '',
#   'voice she hear sure',
#   'dig apples honour',
#   'dig apples',
#   'say rabbit',
#   '',
#   'come help',
#   'sound break glass',
#   'tell pat window',
#   'sure arm yer honour',
#   'he pronounce arrum',
#   'arm goose',
#   'saw size',
#   'fill whole window',
#   'sure yer honour arm',
#   'get business rate go take',
#   'long silence she hear sure yer honour',
#   'tell coward',
#   'last she spread her hand make snatch air',
#   'time little shriek sound break glass',
#   'number cucumber-frames',
#   'think',
#   'wonder',
#   "pull window wish '",
#   'sure want stay',
#   'she wait time hear anything last come rumble little cartwheel sound good many voice talk together she make word ladder -why bring bill get other-bill',
#   'fetch lad -here put corner-no tie first-they reach half high yet-oh',
#   'particular-here bill',
#   'catch hold rope-will roof bear loose slate-oh come',
#   'head',
#   'loud crash -it bill fancy-who go chimney -nay sha',
#   '-bill go down-here bill',
#   'master say go chimney',
#   'oh',
#   'bill get come chimney he',
#   'say she herself',
#   'shy seem put everything upon bill',
#   'bill place good deal fireplace narrow sure think kick little',
#   'she draw her foot chimney she wait till she hear little animal she guess sort scratch scramble chimney close her say herself bill she give sharp kick wait see happen next',
#   'first thing she hear general chorus go bill',
#   'rabbit voice along- catch him hedge',
#   'silence confusion voices- hold his head-brandy now-do choke him-how old fellow',
#   'happen',
#   'tell us',
#   'last come little feeble squeak voice bill think know-no thank ye better now-but deal fluster tell know something come jack-in-the-box go sky-rocket',
#   'old fellow',
#   'say others',
#   'burn house',
#   'say rabbit voice she call loud she set she',
#   'dead silence think herself wonder next',
#   'sense take roof',
#   'minute begin move she hear rabbit say barrowful begin',
#   'barrowful',
#   'think she long doubt next moment shower little pebbles come rattle window hit her face',
#   'put stop she say herself better',
#   'produce dead silence',
#   'she surprise pebbles turn little cake lay floor bright idea come her head',
#   'eat cake she think sure make change size make larger make smaller suppose',
#   'she swallow cake delight find she begin',
#   'she small get door she run house quite crowd little animals wait',
#   'poor little lizard bill middle hold guinea-pigs give something bottle',
#   'make rush she moment she appear she run she find herself safe thick wood',
#   'first thing get say she herself she wander wood grow right size second thing find way garden',
#   'think best plan',
#   'sound excellent plan doubt arrange difficulty she smallest idea set she peer tree little sharp bark her head make her look great hurry',
#   'enormous puppy look her large round eye stretch paw try touch her',
#   'poor little thing',
#   'say she coax tone she try hard whistle she frighten time think hungry case eat her spite her coax',
#   'know she she pick little bite stick hold puppy whereupon puppy jump air feet yelp delight rush stick make believe worry she dodge great thistle keep herself run moment she appear side puppy make rush stick tumble head heel hurry get hold she think game play cart-horse expect moment trample feet run puppy begin series short charge stick run little way forward time long way bark last sit good way pant tongue hang mouth great eye half shut',
#   'seem good opportunity make her escape she set run till she tire breath till puppy bark sound faint distance',
#   'dear little puppy',
#   'say she she lean buttercup rest herself she herself leave teach much if-if right size',
#   'dear',
#   'forget get grow',
#   'let see-how manage',
#   'suppose eat drink something great question',
#   'great question',
#   'she look her she grass she see anything look right thing eat drink circumstances',
#   'large mushroom grow her height herself she look occur her she look see top',
#   'she stretch herself tiptoe peep edge mushroom her eye meet large blue caterpillar sit top arm fold smoke long hookah take smallest her anything',
#   'advice caterpillar caterpillar she look time silence last caterpillar take hookah mouth her languid sleepy voice',
#   '',
#   'say caterpillar',
#   'encourage open conversation',
#   'shyly know sir present-at least know get morning think change several time',
#   'mean',
#   'say caterpillar',
#   'explain',
#   'explain afraid sir say see',
#   'see say caterpillar.',
#   'afraid put reply understand begin many different size day confuse',
#   'say caterpillar',
#   'find say she turn chrysalis-you day butterfly think feel little queer',
#   'bite say caterpillar',
#   'feel different say she know feel queer',
#   '',
#   'say caterpillar',
#   '',
#   'bring begin conversation',
#   'she felt little irritate caterpillar make short remark she draw herself say think tell',
#   '',
#   'say caterpillar',
#   'puzzle question she think good reason caterpillar seem unpleasant state she turn',
#   'come',
#   'caterpillar call her',
#   'something important say',
#   'sound promise she turn come',
#   'keep say caterpillar',
#   '',
#   'say she her anger well she',
#   'say caterpillar',
#   'she think she wait she nothing tell her something worth hear',
#   'minutes puff speak last unfold arm take hookah mouth say think change',
#   'afraid sir say she remember things used-and keep size ten minutes',
#   'remember things',
#   'say caterpillar',
#   'try say doth little busy she come different',
#   'melancholy voice',
#   'repeat old father william say caterpillar',
#   'she fold her hand begin old father william young man say hair become white stand head- think age right',
#   'youth father william reply his son fear injure brain sure none',
#   'old say youth mention grow fat turn back-somersault door- pray reason',
#   'youth say sage he shake his grey lock keep limbs supple use ointment-one shill box- allow sell couple',
#   'old say youth jaw weak anything tougher suet finish goose bone beak- pray manage',
#   'youth say his father take law argue case she muscular strength give jaw last rest life',
#   'old say youth suppose eye steady balance eel end nose- make clever',
#   'answer question enough say his father give air',
#   'think listen day stuff',
#   'kick stairs',
#   'say right say caterpillar',
#   'right afraid say word get alter',
#   'wrong begin end say caterpillar silence minutes',
#   'caterpillar speak',
#   'size want',
#   'ask',
#   'oh particular size she reply change know',
#   'know say caterpillar',
#   'she say nothing she contradict her life she felt she lose her temper',
#   'content',
#   'say caterpillar',
#   'little larger sir mind say she inch wretched height',
#   'good height',
#   'say caterpillar rear upright speak inch high',
#   'use',
#   'plead poor she piteous tone',
#   'she think herself wish creatures offend',
#   'get use time say caterpillar put hookah mouth begin smoke',
#   'time she wait choose speak',
#   'minute caterpillar take hookah mouth yawn shake',
#   'get mushroom crawl grass remark go side make grow taller side make grow shorter',
#   'side',
#   'side',
#   'think she herself',
#   'mushroom say caterpillar she ask aloud moment sight',
#   'she remain look mushroom minute try make side round she find difficult question',
#   'last she stretch her arm round go break bite edge hand',
#   '',
#   'she say herself nibble little right-hand bite try effect next moment she felt violent blow her chin strike her foot',
#   'she good deal frighten sudden change she felt time lose she shrink she set work eat bite',
#   'her chin press her foot room open her mouth she last manage swallow morsel lefthand bite',
#   'come head free last',
#   'say she tone delight change alarm moment she find her shoulder nowhere find she see she look immense length neck seem rise stalk sea green leave lay her',
#   'green stuff',
#   'say she',
#   'shoulder get',
#   'oh poor hand see',
#   'she move she speak result seem follow little shake distant green leave',
#   'seem chance get her hand her head she try get her head delight find her neck bend direction serpent',
#   'she succeed curve graceful zigzag go dive leave she find nothing top tree she wander sharp hiss make her draw hurry large pigeon fly her face beat her wing',
#   'serpent',
#   'scream pigeon.',
#   'serpent',
#   'say she',
#   'let',
#   'serpent say',
#   'repeat pigeon subdue tone add kind sob try way nothing seem suit',
#   'least idea talk say she',
#   'try root tree try bank try hedge pigeon go attend her serpents',
#   'please',
#   'she puzzle she think use say anything till pigeon finish',
#   'trouble enough hatch egg say look-out serpents night day',
#   'wink sleep weeks',
#   'sorry annoy say she begin see mean',
#   'take highest tree wood continue pigeon raise voice shriek think free last need come sky',
#   'ugh serpent',
#   'serpent tell',
#   'say',
#   'a- a-',
#   '',
#   'say pigeon.',
#   'see try invent something',
#   'little girl say she she remember number change she go day',
#   'likely story',
#   'say pigeon tone deepest contempt',
#   'see good many little girls time neck',
#   '',
#   'serpent use she',
#   'tell next taste egg',
#   'taste egg say truthful child little girls eat egg much serpents know',
#   'believe say kind serpent say',
#   'new idea she she silent minute give pigeon opportunity add look egg know matter little girl serpent',
#   'matter good deal say she look egg happen want raw',
#   '',
#   'say pigeon sulky tone settle nest',
#   'crouch tree well she her neck keep get entangle branch she stop untwist',
#   'she remember she hold piece mushroom her hand she set work nibble first grow taller shorter she succeed bring herself her usual height',
#   'she anything right size felt strange first she get use minutes begin talk herself usual',
#   'come half plan',
#   'puzzle change',
#   'sure go minute',
#   'get right size next thing get beautiful garden-how wonder',
#   'she say she come open place little house feet high',
#   'live think come size frighten wits',
#   'she begin nibble righthand bite venture go house till she bring herself inch high',
#   'pig minute she stand look house wonder footman livery come run wood- she consider him footman he livery judge his face she call him fish -and rap door his knuckle',
#   'open footman livery round face large eye frog footmen she powder hair curl head',
#   'she felt curious know creep little way wood listen',
#   'fish-footman begin produce his arm great letter large himself he hand say solemn tone duchess',
#   'invitation she play croquet',
#   'frog-footman repeat solemn tone change order word little she',
#   'invitation duchess play croquet',
#   'low curl get',
#   'much she run wood fear her she next peep fish-footman go sit grind door she sky',
#   'she go door knock',
#   'sort use knock say footman reason',
#   'side door make noise hear',
#   'extraordinary noise go within-a constant howl sneeze great crash dish kettle break piece',
#   'please say she get',
#   'sense knock footman go her door us',
#   'instance knock let know',
#   'he look sky time he speak she think uncivil',
#   'he help she say herself his eye top his head',
#   'rate he answer questions.-how get',
#   'she repeat aloud.',
#   'sit footman remark till tomorrow- moment door house open large plate come skim straight footman head graze his nose break piece tree him',
#   '-or next day footman continue tone nothing happen',
#   'get',
#   'ask she louder tone',
#   'get',
#   'say footman',
#   'first question know',
#   'doubt she tell',
#   'dreadful she mutter herself way creatures argue',
#   'drive crazy',
#   'footman seem think good opportunity repeat his remark variations.',
#   'sit he say days days',
#   '',
#   'say she',
#   'anything say footman begin whistle',
#   'use talk him say he idiotic',
#   'she open door go',
#   'door lead large kitchen full smoke end duchess sit three-legged stool middle nurse baby cook lean fire stir large cauldron seem full soup',
#   'much soup',
#   'she say herself she sneeze',
#   'air',
#   'duchess sneeze baby sneeze howl moment pause',
#   'things kitchen sneeze cook large cat sit hearth grin ear ear',
#   'please tell say she she sure good manners her speak first cat grin',
#   'cheshire cat say duchess',
#   'pig',
#   'she say last word sudden violence she jump she saw moment address her she take courage go know cheshire cat grin fact know cat grin',
#   "say duchess 'em",
#   'know she say feel please get conversation',
#   'know say duchess fact',
#   'she tone remark think introduce subject conversation',
#   'she try fix cook take cauldron soup fire set work throw everything her reach duchess baby-the fire-irons come follow shower saucepans plat dish',
#   'duchess take notice hit her baby howl much impossible say blow hurt',
#   'oh please mind',
#   'cry she jump agony terror',
#   'go his precious nose',
#   'large saucepan fly she',
#   'everybody mind business duchess say hoarse growl world go round deal',
#   'advantage say she felt she get opportunity show little her knowledge',
#   'think work make day night',
#   'see earth take twenty-four hours turn round axis- talk ax say duchess chop her head',
#   'she glance cook see she mean take hint cook stir soup seem listen she go twenty-four hours think twelve',
#   'say duchess abide figure',
#   'she begin her child sing sort lullaby she give violent shake end line speak little boy beat him he sneeze he annoy he know tease',
#   'chorus',
#   'cook baby join wow',
#   'wow',
#   'wow',
#   'duchess sing second verse song she keep toss baby poor little thing howl she hear word speak boy beat him he sneeze he enjoy he please',
#   'chorus',
#   'wow',
#   'wow',
#   'wow',
#   '',
#   'nurse bite',
#   'duchess say she fling baby her she spoke.',
#   'go get ready play croquet she hurry room',
#   'cook throw frying-pan her she go her',
#   'catch baby difficulty queer-shaped little creature hold arm legs directions star-fish think she',
#   'poor little thing snort steam-engine she catch keep double straighten first minute much she hold',
#   'she make proper way nurse twist sort knot keep tight hold right ear leave foot prevent undo she she open air',
#   'take child think sure kill day murder leave',
#   'she say last word loud little thing grunt reply leave sneeze time',
#   'grunt say she proper way express',
#   'baby grunt she look face see matter',
#   'doubt turn-up much snout real nose eye get small baby she look thing',
#   'sob she think look eye see tear',
#   'tear',
#   'go turn pig dear say nothing',
#   'mind',
#   'poor little thing sob grunt impossible say go silence',
#   'think herself creature get home',
#   'grunt she look face alarm',
#   'time mistake less pig she felt absurd her she',
#   'she set little creature felt relieve see trot wood',
#   'grow she say herself make child make handsome pig think',
#   'she begin think children she know pig say herself know right way change them- she little startle see cheshire cat sit tree yards',
#   'cat grin saw she',
#   'look good-natured she think claw great many teeth she felt treat respect',
#   'cheshire puss she begin timidly she know like name grin little wider',
#   'come please think she she go',
#   'tell please way go',
#   'depend good deal want get say cat.',
#   'much care where- say she',
#   'matter way go say cat',
#   '-so long get add explanation',
#   'oh sure say cat walk',
#   'she felt she she try question',
#   'sort people live',
#   'direction cat say wave right paw round live hatter direction wave paw live march hare',
#   'visit mad',
#   'want go mad people she remark',
#   'oh help say cat mad',
#   'mad',
#   'mad',
#   'know mad',
#   'say she',
#   'say cat come',
#   'she think she go know mad',
#   'begin say cat dog mad',
#   'grant',
#   'suppose say she',
#   'cat go see dog growl angry wag tail please',
#   'growl please wag tail angry',
#   'mad',
#   'call purr growl say she',
#   'call say cat',
#   'play croquet she to-day',
#   'much say she invite',
#   'see say cat vanish',
#   'much surprise she get use queer things happen',
#   'she look place appear',
#   'by-the-bye become baby',
#   'say cat.',
#   'forget ask',
#   'turn pig she say come natural way.',
#   'think say cat vanish',
#   'little half expect see appear minute she walk direction march hare say live',
#   'see hatters she say herself march hare much interest rave mad-at least mad march',
#   'she say she look cat sit branch tree',
#   'say pig fig',
#   'say cat.',
#   'say pig reply she wish keep appear vanish make quite giddy',
#   'right say cat time vanish begin end tail end grin remain time rest go',
#   '',
#   'see cat grin think grin cat',
#   'curious thing saw life',
#   'she go she come sight house march hare she think house chimneys shape ears roof thatch fur',
#   'large house she go nearer till she nibble lefthand bite mushroom raise herself feet high she walk say herself suppose rave mad',
#   'wish go see',
#   'mad tea-party table set tree front house march hare hatter tea dormouse sit use cushion rest elbow talk head',
#   'uncomfortable dormouse think asleep suppose mind',
#   'table large crowd corner room',
#   'room',
#   'cry saw come',
#   'plenty room',
#   'say she she sit large arm-chair end table',
#   'wine march hare say encourage tone',
#   'she look round table nothing tea.',
#   'see wine she remark',
#   'say march hare',
#   'civil offer say she',
#   'civil sit invite say march hare.',
#   'know table say she lay great many',
#   'hair want cut say hatter',
#   'he look she time great curiosity his first speech',
#   'learn make personal remark she say severity rude',
#   'hatter open his eye wide hear he say she writing-desk',
#   'come fun',
#   'think',
#   'she begin ask riddles.- believe guess she add aloud',
#   'mean think find answer',
#   'say march hare',
#   'say she',
#   'say mean march hare go',
#   'reply least-at least mean say-that thing know',
#   'thing bite',
#   'say hatter',
#   'say see eat thing eat see',
#   'say march hare get thing get',
#   'say add seem talk his sleep breathe sleep thing sleep breathe',
#   'thing say hatter conversation drop party sit silent minute she think she remember she writing-desks much',
#   'hatter break silence',
#   'day month',
#   'he say turn she he take his watch his pocket look shake hold his ear',
#   'she consider little say fourth',
#   'days wrong',
#   'sigh hatter.',
#   'tell butter suit work',
#   'he add look march hare',
#   'best butter march hare reply',
#   'crumb get grumble put bread-knife',
#   'march hare take watch look he dip his cup tea look he think nothing say his first remark best butter know',
#   'she look his shoulder curiosity',
#   'funny watch',
#   'she remark',
#   "day month tell o'clock",
#   '',
#   'mutter hatter',
#   'watch tell year',
#   'course she reply stay year time',
#   'case mine say hatter',
#   'she felt puzzle',
#   'hatter remark seem sort mean english.',
#   'understand she say she',
#   'dormouse asleep say hatter he pour little hot tea nose',
#   'dormouse shake head say open eye course course go remark',
#   'guess riddle',
#   'hatter say turn she',
#   'give she reply answer',
#   'slightest idea say hatter',
#   'say march hare',
#   'sigh wearily.',
#   'think something better time she say waste ask riddle answer',
#   'know time say hatter talk waste',
#   'him',
#   'know mean say she',
#   'course',
#   'hatter say his head contemptuously.',
#   'dare say speak time',
#   'reply know beat time learn music',
#   'ah',
#   'account say hatter',
#   'he stand beat',
#   'keep good term him he anything clock',
#   'instance suppose morning time begin lessons whisper hint time round go clock twinkle',
#   'half-past time dinner',
#   'wish march hare say whisper',
#   'grand say she then- hungry know',
#   'first say hatter keep half-past long',
#   'way manage',
#   'she ask',
#   'hatter shake his head',
#   '',
#   'he reply',
#   'quarrel last march-just he go mad know- point his tea spoon march hare -it great concert give she hearts sing twinkle little bat',
#   'wonder',
#   'know song',
#   'hear something say she',
#   'go know hatter continue way world fly tea-tray sky',
#   'twinkle twinkle- dormouse shake begin sing sleep twinkle twinkle twinkle twinkle- go long pinch make stop',
#   'finish first verse say hatter she jump bawl murder time',
#   'his head',
#   'savage',
#   'exclaim she',
#   'hatter go mournful tone he thing ask',
#   "o'clock",
#   'bright idea come she head',
#   'reason many tea-things put',
#   'she ask',
#   'yes say hatter sigh tea-time time wash things whiles',
#   'keep move round suppose',
#   'say she',
#   'say hatter things get use',
#   'happen come begin',
#   'she venture ask',
#   'suppose change subject march hare interrupt yawning.',
#   'get tire',
#   'vote young lady tell us story',
#   'afraid know say she alarm proposal',
#   'dormouse',
#   'cry',
#   'wake dormouse',
#   'pinch side',
#   'dormouse open his eyes.',
#   'asleep he say hoarse feeble voice hear word fellows say',
#   'tell us story',
#   'say march hare',
#   'please',
#   'plead she',
#   'quick add hatter asleep',
#   'time little sisters dormouse begin great hurry name she she she live bottom well- live',
#   'say she take great interest question eat drink',
#   'live treacle say dormouse think',
#   'know remark ill. say ill. she try she herself extraordinary ways live like puzzle her much she go live bottom',
#   'take tea march hare say she',
#   'nothing reply offend tone take',
#   'mean take less say hatter easy take nothing',
#   'nobody ask opinion say she',
#   'make personal remark',
#   'hatter ask',
#   'know say she help herself tea bread-and-butter turn dormouse repeat her question',
#   'live bottom',
#   'dormouse take minute think say treacle-well',
#   'thing',
#   'begin hatter march hare go sh',
#   'sh',
#   'dormouse remark civil finish story',
#   'please go',
#   'she say interrupt',
#   'dare say',
#   '',
#   'say dormouse',
#   'he consent go',
#   'little sisters-they learn draw know- draw',
#   'say she forget her promise',
#   'treacle say dormouse consider time.',
#   'want clean cup interrupt hatter let move place',
#   'he he speak follow him march hare move dormouse place she take place march hare',
#   'hatter get advantage change she good deal worse march hare upset milk-jug his plate',
#   'wish offend dormouse she begin understand',
#   'draw treacle',
#   'draw water water-well say think draw treacle treacle-well-eh stupid',
#   'say dormouse choose notice last remark',
#   'course say -well',
#   'answer confuse poor she she let dormouse go time interrupt',
#   'learn draw dormouse go yawn rub eye get sleepy draw manner things-everything begin',
#   'say she',
#   '',
#   'say march hare',
#   'she silent',
#   'dormouse close eye time go doze pinch hatter wake little shriek go begin mouse-traps moon memory muchness-you know say things much muchness -did see thing draw muchness',
#   'ask say confuse think- talk say hatter',
#   'piece rudeness she bear she get great disgust walk dormouse fell others take least her go she look half hop call her last time she saw try put dormouse teapot',
#   'rate go',
#   'say she she pick her way wood',
#   'stupidest tea-party life',
#   'she say she notice tree door lead right',
#   'curious',
#   'she think',
#   'everything curious today',
#   'think go',
#   'she go',
#   'she find herself little glass table',
#   'manage better time she say herself begin take little golden key unlock door lead garden',
#   'she go work nibble mushroom she keep piece her pocket till she foot high she walk little passage then-she find herself last beautiful garden bright flower-beds cool fountains',
#   'she croquet-ground large rose-tree stand entrance garden roses grow white gardeners paint red',
#   'she think curious thing she go nearer watch she come she hear say look',
#   'go splash paint',
#   'help say sulky tone jog elbow',
#   'look say right',
#   'lay blame others',
#   'better talk',
#   'say five.',
#   'hear she say yesterday deserve behead',
#   '',
#   'say speak',
#   'none business',
#   'say',
#   'his business',
#   'say tell him-it bring cook tulip-roots onions',
#   'fling his brush begin unjust things- his eye chance fall she she stand watch he check himself others look round bow low',
#   'tell say she paint roses',
#   'say nothing look',
#   'begin low voice fact see miss red rose-tree put white mistake she find head cut know',
#   'see miss best she come to- moment look garden call she',
#   'she',
#   'gardeners throw flat face',
#   'many footsteps she look round eager see she',
#   'come soldier she club shape gardeners flat hand feet corner next ten courtiers ornament diamonds walk soldier',
#   'come royal children little dears come jump hand hand couple ornament hearts',
#   'next come guests kings she she recognise white rabbit talk hurry nervous manner smile everything say go her',
#   'follow knave hearts she king crown crimson she cushion last grand procession come king she hearts',
#   'she doubtful she lie her face gardeners she remember hear rule processions besides use procession think she people lie upon face see',
#   'she stand she wait',
#   'procession come opposite she stop look her she say',
#   'she say knave hearts bow smile reply',
#   'idiot',
#   'say she her head turn she she go name child',
#   'name she please majesty say she she add herself pack card',
#   'afraid',
#   '',
#   'say she point gardeners lie round rose-tree see lie face pattern rest pack she tell gardeners soldier courtiers her children',
#   'know',
#   'say she surprise her courage',
#   'business mine',
#   'she turn crimson fury glare her moment wild beast scream her head',
#   'off- nonsense',
#   'say she she silent',
#   'king lay his hand her arm say consider dear she child',
#   'she turn him say knave turn',
#   'knave foot',
#   'get',
#   'say she shrill loud voice gardeners jump begin bow king she royal children everybody',
#   'leave',
#   'scream she',
#   'make giddy',
#   'turn rose-tree she go',
#   'please majesty say humble tone go knee he speak trying- see',
#   'say she examine roses',
#   'head',
#   'procession move soldier remain execute unfortunate gardeners run she protection',
#   'behead',
#   'say she she put large flower-pot stand',
#   'soldier wander minute look march others',
#   'head',
#   'shout she',
#   'head go please majesty',
#   'soldier shout reply',
#   'right',
#   'shout she',
#   'play croquet',
#   'silent look she question mean her',
#   '',
#   'shout she',
#   'come',
#   'roar she she join procession wonder happen next',
#   "it's-it fine day",
#   'say timid voice her side',
#   'she walk white rabbit peep her face',
#   'say she duchess',
#   'hush',
#   'hush',
#   'say rabbit low hurry tone',
#   'he look his shoulder he speak raise himself tiptoe put his mouth her ear whisper she sentence execution',
#   '',
#   'say she',
#   'say pity',
#   'rabbit ask',
#   'say she think pity',
#   ...],
#  ['hunt snark agony fit lewis carroll millennium fulcrum edition inscribe dear child memory golden summer hours summer sea',
#   'gird boyish garb boyish task eager she wield her spade she friendly intent ask tale he she tell',
#   'rude spirit seethe outer strife unmeet read her pure simple spright deem list hours waste life empty delight',
#   'sweet maid rescue annoy hearts wiser talk unbeguiled',
#   'she he tenderest she heart-love child',
#   'fond thoughts vex soul',
#   'work claim wakeful nights busy days- albeit bright memories sunlit haunt dream gaze',
#   'content preface fit first land fit second bellman speech fit third baker tale fit fourth hunt fit fifth lesson fit sixth barrister dream fit seventh banker fate fit eighth vanish preface thing possible charge write nonsense bring author brief instructive poem base feel convince line bowsprit get mix rudder sometimes',
#   'view painful possibility appeal write proof incapable deed point strong moral purpose poem arithmetical principles inculcate noble teach natural history take prosaic course explain happen',
#   'bellman sensitive appearances use bowsprit unshipped week revarnished happen time come replace board remember end ship belong',
#   'know slightest use appeal bellman he refer his naval code read pathetic tone admiralty instructions none able understand end fasten anyhow rudder',
#   'helmsman use stand his eye he know wrong alas',
#   'rule code speak man helm complete bellman himself word man helm speak',
#   'remonstrance impossible steer till next varnish day',
#   'bewilder intervals ship sail backwards',
#   'poem extent connect lay jabberwock let take opportunity answer question ask pronounce slithy toves',
#   'slithy writhe toves pronounce rhyme groves',
#   'borogoves pronounce borrow',
#   'hear people try give sound worry',
#   'human perversity',
#   'seem fit occasion word poem',
#   'humpty-dumpty theory mean pack word portmanteau seem right explanation',
#   'instance take word fume furious',
#   'make mind say word leave unsettle first',
#   'open mouth speak',
#   'thoughts incline little towards fume say fuming-furious turn hair breadth towards furious say furious-fuming rarest gift balance mind say frumious',
#   'suppose pistol utter well-known word king bezonian',
#   'speak die',
#   'justice shallow felt certain william richard able settle he say name doubt die he gasp rilchiam',
#   'fit first land place snark',
#   'bellman cry he land his crew care support man top tide finger entwine his hair',
#   'place snark',
#   'say twice alone encourage crew',
# ...
#   'form plan frank',
#   'want consult mr',
#   'pomeroy',
#   'give best advice frank',
#   'suppose mean stay village',
#   'sir',
#   'nothing',
#   'go make live grace',
#   'get hard she hoe frank say mr. pomeroy',
#   'decide go',
#   'sir',
#   'go new york',
#   '',
#   'city',
#   'sir',
#   'get something matter',
#   'go live meantime',
#   'get little money',
#   'last long',
#   'know get work black boot streets',
#   'spirit frank stand fair chance succeed',
#   'mean grace',
#   'take her',
#   'think better plan',
#   'leave her till find something',
#   'send her',
#   'leave her deacon pinkerton want put her poorhouse',
#   'bear grace go',
#   'she need',
#   'she stay months',
#   'let pay her board',
#   'afford give her board months',
#   'kind mr. pomeroy kindness',
#   'duty take care grace',
#   'she independence frank',
#   'say',
#   'able mind till pay rate dollars week grace board',
#   'say frank board grace think better go city',
#   'look clothe to-morrow frank say mrs. pomeroy see mend',
#   'start thursday morning day',
#   "o'clock next afternoon he walk main street front deacon pinkerton house he saw tom lean tree",
#   'tom',
#   'he say pass',
#   'go',
#   'tom ask',
#   'mr',
#   'pomeroy',
#   'go live',
#   'tell go',
#   'father',
#   'mistake',
#   'ai pauper',
#   'say tom',
#   'get money',
#   'get hand earn money go try',
#   'advise resign captain baseball club',
#   '',
#   'kick',
#   'think fellows pauper captain',
#   'second time call pauper',
#   'call',
#   'pauper know',
#   'frank quarrelsome boy repeat insult much him',
#   'he seize tom collar trip him leave him grind howl rage',
#   'valor his strong point he resolve revenge frank',
#   'he unable report case his father till next morning deacon return neighbor village whither he go business till late result his communication call mr. pomeroy deacon next morning',
#   'he find frank his intention tom request take him poorhouse',
#   'he',
#   'hero his way new york',
#   'frank get place new york say frank himself he emerge railway station look him interest curiosity',
#   'black yer boot',
#   'shine',
#   'ask bootblack see hero stand',
#   'frank look his shoe',
#   'dirty doubt he felt dispose extravagant consider his limit resources he felt necessary obtain information city',
#   'he say black',
#   'boy his knees work',
#   'much make day',
#   'ask frank',
#   'good day make dollar',
#   'good say frank',
#   'show way broadway',
#   'go',
#   'hero pay his shine start direction indicate',
#   'frank plan he get store',
#   'he know principal business street city he know',
#   'he reach great thoroughfare minutes fortunate enough find window corner store sign boy want',
#   'he go young man put goods',
#   'want boy',
#   'believe boss want',
#   'go desk',
#   'frank find desk propound question sandy-whiskered man look his write',
#   'prompt he say',
#   'put minutes',
#   'saw minute',
#   'want place',
#   '',
#   'know way city',
#   'sir find',
#   '',
#   'plenty applications boys live city familiar streets',
#   'frank leave store discomfit',
#   'he come store similar notice boy want',
#   'dry goods store',
#   'live parent',
#   'ask',
#   'parent dead say frank',
#   'sorry take',
#   'sir',
#   'case take anything make parent responsible',
#   'take anything say frank',
#   'take',
#   'hero leave store little dishearten his second rebuff',
#   'he make several fruitless applications lose courage',
#   'he gain appetite',
#   'surprise his attention draw bill restaurant opposite side street',
#   'he cross stand outside begin examine see scale price',
#   'position he arouse slap',
#   'turn he meet gaze young man thirty smile',
#   'frank boy',
#   'he say offer his hand',
#   'thank say hero bewilder he recollection man call him name',
#   'smile little think she guess his name frank',
#   'delight hear he continue',
#   'reach city',
#   'morning say unsuspecting frank',
#   'queer happen meet',
#   'go stay',
#   'get place',
#   'help',
#   'suppose remember venture hero think name',
#   'jasper wheelock',
#   'mean say remember',
#   'strange meet twice country home',
#   'matter',
#   'ready help',
#   'way din',
#   '',
#   'come dine',
#   'take',
#   'ask jasper wheelock pass bill fare frank.',
#   'think roast beef say frank',
#   'suit',
#   'waiter plat roast beef cup coffee',
#   'home',
#   'ask jasper',
#   'she die',
#   'say say jasper',
#   '',
#   'forget sister name',
#   'grace',
#   'course grace',
#   'find hard remember name',
#   'fact try recall last name go',
#   'fowler',
#   'sure frank fowler',
#   'forgetful',
#   'conversation interrupt arrival coffee roast beet he his new friend attack vigor',
#   'kind pudding',
#   'ask stranger',
#   'apple dumpling say frank',
#   'suit',
#   'apple dumpling',
#   'due time apple dumpling dispose check bring amount seventy cents',
#   'pay say jasper',
#   'thank',
#   'old acquaintances know',
#   'he put his hand his pocket withdraw exclamation surprise good joke he say',
#   'leave money home',
#   'remember leave pocket coat',
#   'borrow money',
#   'hand dollar',
#   'frank suspicious request money make him uneasy',
#   'seem way refuse he draw money',
#   'his companion settle bill lead way street',
#   'jasper wheelock scrupulous he capable borrow money intend return he his good side',
#   'frank say he find street favor go help return',
#   'get much money',
#   '',
#   'dollars leave home pay fare cars dinner seventeen dollars half leave',
#   'necessary get place possible',
#   'sister support grace know',
#   'know',
#   'fact frank impose',
#   'saw whole course life',
#   'make say know',
#   'want get dinner',
#   'trouble pay money',
#   'place weeks first next week',
#   'rest week get nothing try get place',
#   'first thing get room',
#   'tell part room',
#   'expensive',
#   'pay dollar half week',
#   'think old lady charge fifty cents extra',
#   'share dollar',
#   'pay cents',
#   'keep pay',
#   'room sixth avenue',
#   'distance walk',
#   'jasper halt baker shop',
#   'he say',
#   'he draw latch-key enter',
#   'den he say',
#   'large get better money',
#   'satisfy say frank.',
#   'want get cheap',
#   'get economize short time',
#   'week earn fifteen dollars week',
#   'business mr',
#   'wheelock',
#   'journeyman printer',
#   'good business steady work',
#   'expect get start',
#   'give advice',
#   'wish',
#   'know way new york',
#   'believe map',
#   'show position principal streets give clearer idea go',
#   'map find jasper explain frank lead topographical feature island city',
#   'thing want make him content employment',
#   'make inquiries',
#   'think frank say jasper next morning get position cash-boy',
#   'cash-boy',
#   'large retail establishments salesman keep book his sales',
#   'he himself make change many access money-drawer',
#   'money she cashier desk boys purpose return change',
#   'think get situation cash-boy',
#   'try gilbert mack',
#   'know principal salesmen',
#   'vacancy he get oblige',
#   'large retail store broadway',
#   'broad spacious',
#   'twenty salesmen stand counter boys run way small book hand',
#   'duncan',
#   'say jasper',
#   'person address jasper wheelock age',
#   'he keen energetic look manner single lead clerk',
#   'right wheelock',
#   '',
#   'he respond',
#   'want anything line',
#   'goods want place youngster',
#   'he friend mine',
#   'answer his good character',
#   'satisfactory',
#   'sort place he want',
#   'he ready begin cash-boy',
#   'oblige boys fall sick supply his place',
#   'speak mr',
#   'gilbert',
#   'he go mr. gilbert man part store',
#   'mr. gilbert seem question',
#   'frank wait result suspense dread disappointment time he fortunate',
#   'boy stay report duncan',
#   'his wag dollars week',
#   'much frank please feel last he place city',
#   'he letter grace announce his success express she he able send her',
#   'cash boy adventure weeks pass',
#   'duties cash-boy simple enough frank difficulty discharge',
#   'he find tiresome his feet day cash-boys allow sit he get use young strong',
#   'satisfactory thing give frank uneasiness',
#   'his income inadequate his want',
#   'make glum frank',
#   'ask jasper wheelock',
#   'look glum',
#   'say frank.',
#   'think earn money',
#   'know little get',
#   'take care take care grace',
#   'lend money frank',
#   'thank good advice get lay',
#   'thank jasper help matter',
#   'owe money know pay',
#   'increase income know say jasper.',
#   'afraid gilbert mack raise wag',
#   'expect',
#   'rest cash-boys ask thing',
#   'true know please',
#   'duncan tell work rest boys',
#   'try',
#   'he say make good salesman he think',
#   'course young',
#   'suppose',
#   'frank earn fifteen dollars week know get save let give',
#   'feel necessary',
#   'jasper true friend say frank right accept kind offer forget',
#   'good friend',
#   'frank',
#   'look',
#   'hear something',
#   'small frank income he manage live',
#   'remember he pay fifty cents week room',
#   'great economy he make his meals cost dollars week his dollars he save fifty cents',
#   'save sufficient pay his clothe',
#   'he buy his little fund amount dollars',
#   'sum he inclose sic dollars mr. pomeroy pay weeks board grace.',
#   'she able keep he say himself',
#   'rate get enough pay weeks',
#   'time something turn',
#   'several days pass show frank way he increase his income',
#   'jasper offer give him dollars week his wag hero refuse',
#   'friday store close head salesman call frank him',
#   'live',
#   'he ask',
#   'sixth avenue twenty-fifth street',
#   'bundle go forty-sixth street',
#   'pay fare stage she',
#   'promise send to-night disappoint lady',
#   'she',
#   'frank take bundle get board pass omnibus',
#   'seat vacant beside old gentleman seventy feeble',
#   'forty-fifth street he pull strap prepare descend lean his cane he',
#   'mischance horse start little old man lose his foot fell street',
#   'frank accident spring his help.',
#   'she much hurt sir',
#   'he say hastily.',
#   'hurt knee say old gentleman',
#   'let assist sir say frank help him',
#   'thank boy',
#   'live number forty-five close',
#   'lead door house indebted',
#   'sir',
#   'trouble',
#   'slow step support hero old gentleman walk his door',
#   'open maid servant look surprise frank.',
#   'fell she explain her master young gentleman help home',
#   'much sir',
#   '',
#   'anything sir',
#   'ask frank',
#   'come moment',
#   'hero follow his new acquaintance furnish parlor',
#   'young friend tell take way attention',
#   'oh sir intend get next street',
#   'dinner ready',
#   'stop dine',
#   'thank sir he say promise she bundle',
#   'believe want',
#   '',
#   'say house next street',
#   'go return minutes',
#   'service power something return',
#   'think frank he help employment',
#   'aloud thank sir come',
#   'minutes frank usher handsome dining-room',
#   'dinner table chair set',
#   'head table course old gentleman opposite mrs. bradley his housekeeper side place frank',
#   'mrs. bradley say old gentleman young gentleman kind enough help home accident speak',
#   'mention his name leave him',
#   'frank fowler sir',
#   'name wharton',
#   'introduce talk',
#   'soup mr',
#   'fowler',
#   'ask housekeeper',
#   'she tall thin woman reserve manner repellant',
#   'she nod introduction fix her eye face hero',
#   'evident impression service render make upon mr. wharton calculate warm housekeeper cordiality',
#   'thank he answer he help feel time mrs. bradley agreeable woman',
#   'good appetite say mr. wharton',
#   'work day',
#   'young friend cash-boy gilbert mack mrs. bradley',
#   'oh',
#   'say mrs. bradley arch her brows much say invite strange company dinner',
#   'parent live city frank believe name frank',
#   'sir dead',
#   'die weeks',
#   'brothers sisters',
#   'sister grace',
#   'suppose she city',
#   'sir',
#   'leave her country',
#   '',
#   'ask dinner',
#   'engagement stay part',
#   'thank sir',
#   'frank accept invitation he know jasper wonder become him',
#   'he saw old gentleman dispose him his present circumstances he friend',
#   'proportion mr. wharton become cordial mrs. bradley become frosty last old gentleman notice her manner',
#   'feel bradley',
#   'he asked.',
#   'little headache say housekeeper',
#   'better something',
#   'pass sir',
#   'arise dinner table mr. wharton follow frank ascend staircase front room second floor fit library',
#   'make him take notice cash-boy',
#   'say mrs. bradley herself',
#   'boy remind somebody',
#   '',
#   'unexpected engagement take seat frank say mr. wharton point luxurious armchair side cheerful grate fire take tell',
#   'thank sir say hero',
#   'his confidence mr. wharton kind tone he briefly recount his story',
#   'conclusion mr. wharton say old frank',
#   'fourteen sir',
#   'brave good boy deserve success',
#   'thank sir',
#   'bind say hard task',
#   'know sir',
#   'let sister go years older able her',
#   'ashamed sir he said.',
#   'promise she take care grace',
#   'much earn cash-boy',
#   'dollars week',
#   'dollars week',
#   'pay expense',
#   'say old gentleman surprise',
#   'sir',
#   'pay fifty cents week room meals cost much',
#   'want clothe',
#   'enough present lay fifty cents week buy need',
#   'buy many twenty-six dollars year',
#   'anything sister expense',
#   'puzzle sir say frank fix trouble glance fire.',
#   'work grace',
#   '',
#   'copy much chance get copy',
#   'good handwrite',
#   'fair sir',
#   'let see specimen',
#   'pen ink table sheet paper',
#   'frank seat himself table write his name paper',
#   'good say his host',
#   'hand good copyist correct suppose work kind hard get',
#   'good reader',
#   'mean read aloud sir',
#   '',
#   'try wish',
#   'take book table book let hear read',
#   'frank open first book come hand irving read clear unembarrassed voice half page',
#   'good',
#   'say mr. wharton',
#   'teach',
#   'attend school',
#   'town school sir',
#   'rate make good use advantage',
#   'good sir',
#   'ask frank',
#   'people pay read',
#   'general suppose case person eye weak likely affect use',
#   'suppose person secure service good clear distinct reader think he pay something',
#   'suppose',
#   'know person',
#   'ask frank.',
#   'describe frank',
#   'year strain eye dare much gaslight',
#   'mrs. bradley housekeeper read she duties think she enjoy',
#   'get read employ',
#   'wish mr. wharton say frank eagerly.',
#   'best',
#   'doubt question ask higher salary afford pay',
#   'dollar week',
#   'ask frank.',
#   'think complain say mr. wharton',
#   'engage reader',
#   'thank sir',
#   'pay make mind pay dollars week',
#   'dollars week',
#   'frank repeat',
#   'much service worth sir',
#   'let judge frank',
#   'know thank sir say frank gratefully.',
#   'expect rich',
#   'trouble pay grace board clothe',
#   'want begin read',
#   'begin to-night engagement',
#   'oh sir nothing',
#   'take post read lead editorial',
#   'tell read',
#   'frank read half hour knock hear door',
#   'come say mr. wharton',
#   'mrs. bradley enter soft quiet step.',
#   'think sir she begin like read usual',
#   'thank mrs. bradley go relieve portion labor',
#   'young friend come read',
#   '',
#   'ejaculate housekeeper tone displeasure sharp glance frank indicate great amount cordiality',
#   'intrude take leave',
#   'something her tone make frank feel uncomfortable',
#   'housekeeper nephew mean say mr. wharton housekeeper withdraw imagine intrude',
#   'come sit',
#   'thank sir say mrs. bradley measure tone',
#   'considerate sure excuse come',
#   'mrs. bradley good many years explain mr. wharton dare say she feel little disturb see her place duty',
#   'afraid she offend sir say frank',
#   'explain matter her',
#   'go read frank',
#   'half-past mr. wharton take his watch',
#   'get he said.',
#   'doubt tire need rest',
#   'tire sir',
#   'believe go bed early',
#   'keep later',
#   'think find way',
#   'sir',
#   'come to-morrow',
#   'little',
#   'punctual',
#   'jasper wait him anxiety unusual frank late',
#   'frank',
#   'he exclaim pretty time come home',
#   'begin think get trouble',
#   'go nearest station house search',
#   'different place jasper',
#   'frank tell his story include account his engagement',
#   'seem lose company',
#   'sorry she she',
#   'better expect say frank satisfaction',
#   'sort man mr',
#   'wharton',
#   'say jasper',
#   'he kind generous',
#   'she good friend',
#   'thing likely disagreeable',
#   '',
#   'housekeeper her name mrs. bradley reason she want',
#   'make think',
#   'her manner way she speak',
#   'she come read wharton last seem take her place',
#   'she jealous',
#   'take care her',
#   'she endeavor dismiss',
#   'treat her think her',
#   'housekeeper leave library go her room dudgeon',
#   'mr. wharton fool',
#   ...]]

# %%
def ten_neighbours(pronoun, list_):
    
    """
    extract 5 words before and 5 words after a female word
    
    """
    idx = list_.index(pronoun) # save location of pronoun
    words = list_[:] # copy list into new variable so we don't change it
    words.remove(pronoun) # remove all pronouns from the list 
    left_slice = idx-5 # start of range
    left_slice = min(max(0,left_slice),len(words)-6) # account for edges
    right_slice = left_slice+6 # end of range is straightforward now
    return words[left_slice:right_slice]

# %%
she_pronouns=["she", "her", "hers", "herself"]

# %%
extra_punct=["``", "-", ":", "'", "--"]
female_sentences_all_together=list(flatten(female_sentences_replaced))
female_words_all=[]
for pronoun in she_pronouns:
    remaining_she_pronouns=she_pronouns.copy()
    remaining_she_pronouns.remove(pronoun)
    for sent in female_sentences_all_together:        
        try: 
            s=sent.split()
            s=[word for word in s if word not in remaining_she_pronouns] # remove female pronouns from the sentence
            s=[word for word in s if word not in extra_punct] # remove remaining punctuations            
            female_words_all.append(ten_neighbours(pronoun, s))
            
        except ValueError:  # if there is no pronoun in the sentence, jump to next one
            continue

# %%
print(len(female_words_all)), print(female_words_all[:3])
# Out:
# 854091
# [['illustration', 'adventure', 'wonderland', 'lewis', 'carroll', 'millennium'], ['evidence', 'rabbit-hole', 'she', 'begin', 'get', 'tire'], ['consider', 'mind', 'well', 'she', 'hot', 'day']]
# (None, None)

# %%
# word frequencies around female words
from collections import Counter

female_word_counts = Counter(list(flatten(female_words_all)))
female_word_counts=female_word_counts.most_common()
female_word_counts[:10]
# Out:
# [('she', 111657),
#  ('say', 86976),
#  ('he', 75067),
#  ('his', 54730),
#  ('go', 43934),
#  ('come', 32968),
#  ('little', 32386),
#  ('him', 29224),
#  ('look', 27147),
#  ('think', 26489)]

# %%
# export female words list
female_words=list(flatten(female_words_all))
with open('female_words.txt', 'w') as f:
    for item in female_words:
        f.write("%s\n" % item)

# %%
female_words_df=pd.DataFrame(female_word_counts, columns=["term", "freq"])
female_words_df.to_csv("female_words_df.csv")

# %%
# drop rows with pronouns
female_words_df["pron"]=np.where((female_words_df["term"]=="she")|
                        (female_words_df["term"]=="he")|
                        (female_words_df["term"]=="her")|
                        (female_words_df["term"]=="his")|
                       (female_words_df["term"]=="hers")|
                       (female_words_df["term"]=="herself")|
                       (female_words_df["term"]=="himself")|
                       (female_words_df["term"]=="mr")|
                       (female_words_df["term"]=="mrs.")|
                       (female_words_df["term"]=="mrs")|                       
                        (female_words_df["term"]=="mr."),1,0)
female_words_df_wo_pron=female_words_df[female_words_df["pron"]==0]

# %%
# Visualize 
vis_df=female_words_df_wo_pron[:20]
import seaborn as sns
sns.set(style="ticks")
# sns.set_palette("pastel")
#plt.figure(figsize=(3,3))
p=sns.barplot(x="freq", y="term",color="mediumaquamarine", data=vis_df)
plt.grid()
plt.xlabel("Term frequency")
plt.ylabel("Term")
plt.show()

# %% [markdown]
# ## Co-occurence matrix  + community detection with the modularity algorithm

# %%
# pairwise combinations by sentences
pair_list_all=[]
# importing required library
import itertools

for i in range(len(female_words_all)):
    # creating a list of elements belonging to integers and strings
    lst = female_words_all[i]

    # simulating permutations of the list in a group of 2
    pair_order_list = itertools.combinations(lst, 2)

    # printing the elements belonging to permutations
    pair_list=list(pair_order_list)

    pair_list_all.append(pair_list)

# %%
# add everything into one list
pair_list_all[0]+=pair_list_all[1]

# %%
i=2
while i<=len(pair_list_all):
    pair_list_all[0]+=pair_list_all[i]
    i+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/hc/qzy2rzvj5cg38v_607m73p640000gn/T/ipykernel_54056/2600691005.py in <module>
#       1 i=2
#       2 while i<=len(pair_list_all):
# ----> 3     pair_list_all[0]+=pair_list_all[i]
#       4     i+=1
#
# IndexError: list index out of range

# %% [markdown]
# **This error above is not an error, it just means that the while loop has stopped.**

# %%
pairwise_combos=pair_list_all[0]

# %%
frequency_list = Counter(tuple(sorted(i)) for i in pairwise_combos)

matrix=pd.DataFrame(frequency_list.items())

# %%
matrix.columns=["bigram", "freq"]

# %%
matrix
# Out:
#                              bigram  freq
# 0         (adventure, illustration)     1
# 1        (illustration, wonderland)     1
# 2             (illustration, lewis)     1
# 3           (carroll, illustration)     1
# 4        (illustration, millennium)     1
# ...                             ...   ...
# 2604973            (chelton, right)     1
# 2604974           (efface, instant)     1
# 2604975              (efface, girl)     1
# 2604976              (efface, seem)     1
# 2604977            (efface, others)     1
#
# [2604978 rows x 2 columns]

# %%
matrix[['b1', 'b2']] = pd.DataFrame(matrix['bigram'].tolist(), index=matrix.index)
matrix
# Out:
#                              bigram  freq            b1            b2
# 0         (adventure, illustration)     1     adventure  illustration
# 1        (illustration, wonderland)     1  illustration    wonderland
# 2             (illustration, lewis)     1  illustration         lewis
# 3           (carroll, illustration)     1       carroll  illustration
# 4        (illustration, millennium)     1  illustration    millennium
# ...                             ...   ...           ...           ...
# 2604973            (chelton, right)     1       chelton         right
# 2604974           (efface, instant)     1        efface       instant
# 2604975              (efface, girl)     1        efface          girl
# 2604976              (efface, seem)     1        efface          seem
# 2604977            (efface, others)     1        efface        others
#
# [2604978 rows x 4 columns]

# %%
# export female co-occurence df
matrix.to_csv("female_co_matrix.csv")

# %%
# drop rows with pronouns
matrix["pron"]=np.where((matrix["b1"]=="she")|
                        (matrix["b1"]=="he")|
                        (matrix["b1"]=="her")|
                        (matrix["b1"]=="his")|
                       (matrix["b1"]=="hers")|
                       (matrix["b1"]=="herself")|
                       (matrix["b1"]=="himself")|
                       (matrix["b1"]=="mr")|
                       (matrix["b1"]=="mrs.")|
                       (matrix["b1"]=="mrs")|
                       (matrix["b2"]=="she")|
                        (matrix["b2"]=="he")|
                        (matrix["b2"]=="her")|
                        (matrix["b2"]=="his")|
                       (matrix["b2"]=="hers")|
                       (matrix["b2"]=="herself")|
                       (matrix["b2"]=="himself")|
                       (matrix["b2"]=="mr")|
                       (matrix["b2"]=="mrs.")|
                        (matrix["b2"]=="mr.")|
                        (matrix["b1"]=="mr.")|
                       (matrix["b2"]=="mrs"),1,0)
matrix_wo_pron=matrix[matrix["pron"]==0]

# %%
matrix_wo_pron.to_csv("filtered_wopron_female_matrix.csv")

# %%
import networkx as nx
matrix_nx=matrix_wo_pron[["b1", "b2", "freq"]]
matrix_nx.columns=["source", "target", "weight"]

# %%
matrix_nx
# Out:
#                source        target  weight
# 0           adventure  illustration       1
# 1        illustration    wonderland       1
# 2        illustration         lewis       1
# 3             carroll  illustration       1
# 4        illustration    millennium       1
# ...               ...           ...     ...
# 2604973       chelton         right       1
# 2604974        efface       instant       1
# 2604975        efface          girl       1
# 2604976        efface          seem       1
# 2604977        efface        others       1
#
# [2523831 rows x 3 columns]

# %%
# get first 300 most common word pairs 
matrix_nx=matrix_nx.sort_values(by="weight", ascending=False)
matrix_nx=matrix_nx[:300]

# %%
G = nx.from_pandas_edgelist(matrix_nx, edge_attr='weight')

# %%
import matplotlib.pyplot as plt

# %%
widths = nx.get_edge_attributes(G, 'weight')
for key in widths:    
    widths[key] *=  0.0005
    
d = dict(G.degree)
    
nodelist = G.nodes()

plt.figure(figsize=(6,6))

pos = nx.spring_layout(G, k=0.999, iterations=1)
G.remove_edges_from(nx.selfloop_edges(G))
nodes=nx.draw_networkx_nodes(G,pos,
                       #nodelist=nodelist,
                       node_size=[v * 10 for v in d.values()],
                       node_color='#ffd3b4', linewidths=0.5,
                       alpha=0.9)
nodes.set_edgecolor('white')
nx.draw_networkx_edges(G,pos,
                       edgelist = widths.keys(),
                       width=list(widths.values()),
                       edge_color='grey', alpha=0.3
                       )
nx.draw_networkx_labels(G, pos=pos,
                        labels=dict(zip(nodelist,nodelist)),
                        font_color='black', 
                       font_size=4)
plt.box(False)
plt.savefig("female_words_network.png", format="PNG", dpi=600)
plt.show()

# %% [markdown]
# ### Communities

# %%
import matplotlib.cm

# %%
partition = community_louvain.best_partition(G)
# draw the graph
pos = nx.spring_layout(G, k=0.99, iterations=5)
# color the nodes according to their partition
cmap = matplotlib.cm.get_cmap('Set3', max(partition.values()) + 1)
plt.figure(figsize=(15,15))
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=700,
                   cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_labels(G, pos=pos)
nx.draw_networkx_edges(G,pos, alpha=0.1)
plt.show()

# %%
import networkx.algorithms.community as nxcom
communities = sorted(nxcom.greedy_modularity_communities(G), key=len, reverse=True)
len(communities)
# Out:
# 8

# %%
node_to_community = community_louvain.best_partition(G)
values=list(node_to_community.keys())
node_labels_=dict(zip(values, values))

# %%
np.unique(list(node_to_community.values()))
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
from mycolorpy import colorlist as mcp
import numpy as np
color1=mcp.gen_color(cmap="Set3",n=len(np.unique(list(node_to_community.values()))))
print(color1)
# Out:
# ['#8dd3c7', '#ffffb3', '#fb8072', '#fdb462', '#b3de69', '#d9d9d9', '#ccebc5', '#ffed6f']

# %%
community_to_color=dict(zip(list(np.unique(list(node_to_community.values()))), color1))

# %%
os.getcwd()
# Out:
# '/Users/pazma/Documents/BSE/text_mining/term_project'

# %%
# # alternatively, we can visualize the communities more together
from netgraph import Graph

community_to_color = {
    0 : '#8dd3c7',
    1 : '#ffffb3',
    2 : '#fb8072', 
    3 : '#fdb462',
    4 : '#b3de69',
    5 : '#d9d9d9',
    6 : "#ccebc5", 
    7:  "#ffed6f"
}
node_color = {node: community_to_color[community_id] for node, community_id in node_to_community.items()}

plt.figure(figsize=(5,5))
Graph(G,
      node_color=node_color, node_edge_width=0, edge_alpha=0.1,
      node_layout='community', node_layout_kwargs=dict(node_to_community=node_to_community),
      edge_layout='bundled', edge_layout_kwargs=dict(k=2000), node_labels=node_labels_, 
      node_label_fontdict=dict(size=4)
)
plt.savefig("female_words_communities.png", format="PNG", dpi=600)
plt.show()
# Out:
# /Users/pazma/opt/anaconda3/lib/python3.8/site-packages/netgraph/_node_layout.py:1018: UserWarning: Graph contains a single community. Unable to compute a community layout. Computing spring layout instead.
#   warnings.warn("Graph contains a single community. Unable to compute a community layout. Computing spring layout instead.")
# /Users/pazma/opt/anaconda3/lib/python3.8/site-packages/netgraph/_edge_layout.py:761: RuntimeWarning: invalid value encountered in true_divide
#   displacement = compatibility * delta / distance_squared[..., None]
